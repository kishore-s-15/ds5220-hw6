# %% [markdown]
# ### PROBLEM 4: Knowledge Base Question Answering
#
# Given is knowledge graph with entities and relations, questions with starting entity and answers, and their word embedding . For each question, navigate the graph from the start entity outwards until you find appropriate answer entities.
#
# - there might be multiple answers correct, use F1 to evaluate
# - utils functions (similarity, load_graphs) are given, but you can choose not to use them
# - answers are given to be used for evaluation only
# - your strategy should be a graph traversal augmented with scoring of paths; you might discard paths not promising along the way. This is similar to a focused crawl strategy.
# - for simplicity, the questions are picked so that the answer is always at the end of the relevant path (not intermediary)

# %%
# Importing the required libraries

import heapq
from tqdm import tqdm
from pathlib import Path
from collections import defaultdict

import gensim
import numpy as np
import pandas as pd
import networkx as nx
from nltk import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Setting seed for reproducability

seed = 42
np.random.seed(seed)

# %%
# Data URLs

BASE_DIR = Path().cwd().parent
DATA_DIR = BASE_DIR / "data" / "kbqa"

GRAPH_URL = DATA_DIR / "graph.txt"
ANNOTATIONS_URL = DATA_DIR / "annotations.txt"
WORD_EMBEDDINGS_URL = str(DATA_DIR / "word2vec_train_dev.dat")

# %%
# Function to get the cosine similarity between a relation and query
# Note: Be sure to prepend the relation with ns:
word2vec_model = gensim.models.Word2Vec.load(WORD_EMBEDDINGS_URL)
def get_rel_score_word2vecbase(rel, query):
    if rel not in word2vec_model.wv:
        return 0.0
    words = word_tokenize(query.lower())
    w_embs = []
    for w in words:
        if w in word2vec_model.wv:
            w_embs.append(word2vec_model.wv[w])
    return np.mean(cosine_similarity(w_embs, [word2vec_model.wv[rel]]))


# Function to load the graph from file
def load_graph():
    # Preparing the graph
    graph = defaultdict(list)
    with open(GRAPH_URL) as graph_file:
        lines = graph_file.readlines()
        for line in lines:
            line = eval(line[:-1])
            graph[line[0]].append([line[1], line[2]])
    return graph


# Function to load the queries from file
# Preparing the queries
def load_queries():
    queries = []
    with open(ANNOTATIONS_URL) as annot_file:
        lines = annot_file.readlines()
        for line in lines:
            line = eval(line[:-1])
            queries.append(line)
    return queries

# %%
knowledge_graph = load_graph()
knowledge_graph
# Out:
# defaultdict(list,
#             {'m.01_d4': [['location.citytown.postal_codes', 'm.07nqmhw'],
#               ['location.citytown.postal_codes', 'm.07nqmhf'],
#               ['location.citytown.postal_codes', 'm.01_6pxw'],
#               ['location.location.contains', 'm.021czc'],
#               ['location.citytown.postal_codes', 'm.07nqmj9'],
#               ['travel.travel_destination.tourist_attractions', 'm.02vv_6w'],
#               ['location.citytown.postal_codes', 'm.01_71cx'],
#               ['location.citytown.postal_codes', 'm.07nqmfx'],
#               ['location.citytown.postal_codes', 'm.01_6y3n'],
#               ['location.citytown.postal_codes', 'm.07nqmj2'],
#               ['location.citytown.postal_codes', 'm.01_6p6k'],
#               ['location.citytown.postal_codes', 'm.0gs227r'],
#               ['location.citytown.postal_codes', 'm.01_6s_6'],
#               ['travel.travel_destination.tourist_attractions', 'm.02rvwrv'],
#               ['location.location.contains', 'm.01ky66'],
#               ['location.citytown.postal_codes', 'm.07nqmkm'],
#               ['base.biblioness.bibs_location.country', 'm.09c7w0'],
#               ['location.citytown.postal_codes', 'm.01_6qrp'],
#               ['location.citytown.postal_codes', 'm.01_73_n'],
#               ['location.citytown.postal_codes', 'm.07nqms5'],
#               ['location.location.containedby', 'm.03v0t'],
#               ['location.administrative_division.country', 'm.09c7w0'],
#               ['travel.travel_destination.tourist_attractions', 'm.06_7k'],
#               ['location.citytown.postal_codes', 'm.01_6q9q'],
#               ['travel.travel_destination.tourist_attractions', 'm.03y4l3'],
#               ['location.location.contains', 'm.01l1jx'],
#               ['travel.travel_destination.tourist_attractions', 'm.0c7ln'],
#               ['location.location.contains', 'm.0c7ln'],
#               ['location.location.nearby_airports', 'm.04rjc8'],
#               ['location.location.contains', 'm.0bl8mx'],
#               ['travel.travel_destination.tourist_attractions', 'm.0n4_xtw'],
#               ['location.citytown.postal_codes', 'm.07nqmg_'],
#               ['location.location.nearby_airports', 'm.0d4v7r'],
#               ['location.citytown.postal_codes', 'm.07nqmj9'],
#               ['location.citytown.postal_codes', 'm.07nqmfg'],
#               ['location.citytown.postal_codes', 'm.01_6pp5'],
#               ['location.citytown.postal_codes', 'm.01_7140'],
#               ['location.citytown.postal_codes', 'm.07nqmgk'],
#               ['travel.travel_destination.tourist_attractions', 'm.04h9qj'],
#               ['travel.travel_destination.tourist_attractions', 'm.0j2m3px'],
#               ['location.citytown.postal_codes', 'm.01_6qp4'],
#               ['location.citytown.postal_codes', 'm.01_6v6w'],
#               ['location.citytown.postal_codes', 'm.01_6ps8'],
#               ['location.citytown.postal_codes', 'm.01_6pgd'],
#               ['location.location.nearby_airports', 'm.08qt9p'],
#               ['location.citytown.postal_codes', 'm.07nqmlh'],
#               ['location.citytown.postal_codes', 'm.01_6pmb'],
#               ['location.citytown.postal_codes', 'm.01_6t1b'],
#               ['location.citytown.postal_codes', 'm.01_75zb'],
#               ['location.location.contains', 'm.025v4fb'],
#               ['location.citytown.postal_codes', 'm.01_6s_6'],
#               ['location.citytown.postal_codes', 'm.01_6r1z'],
#               ['location.citytown.postal_codes', 'm.07nqmkm'],
#               ['location.citytown.postal_codes', 'm.07nqmhf'],
#               ['location.citytown.postal_codes', 'm.01_6p6k'],
#               ['location.citytown.postal_codes', 'm.01_6smy'],
#               ['location.citytown.postal_codes', 'm.07nqmj2'],
#               ['location.location.contains', 'm.02jw0z'],
#               ['location.citytown.postal_codes', 'm.01_77qt'],
#               ['travel.travel_destination.tourist_attractions', 'm.01dlzc'],
#               ['location.citytown.postal_codes', 'm.07nqmgs'],
#               ['location.citytown.postal_codes', 'm.01_6pp5'],
#               ['location.location.contains', 'm.02rvwrv'],
#               ['location.citytown.postal_codes', 'm.07nqmg_'],
#               ['location.citytown.postal_codes', 'm.01_795b'],
#               ['location.citytown.postal_codes', 'm.01_6v4j'],
#               ['location.citytown.postal_codes', 'm.07nqmkd'],
#               ['location.location.contains', 'm.01dlzc'],
#               ['location.citytown.postal_codes', 'm.01_6rfw'],
#               ['location.location.contains', 'm.09sh942'],
#               ['location.location.contains', 'm.06_7k'],
#               ['travel.travel_destination.tourist_attractions', 'm.0d9wz'],
#               ['location.citytown.postal_codes', 'm.01_6t95'],
#               ['location.citytown.postal_codes', 'm.01_78lh'],
#               ['location.citytown.postal_codes', 'm.07nqmh6'],
#               ['location.citytown.postal_codes', 'm.01_72xz'],
#               ['travel.travel_destination.tourist_attractions', 'm.0bl8mx'],
#               ['location.citytown.postal_codes', 'm.065rklh'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['travel.travel_destination.tourist_attractions', 'm.027hqc_'],
#               ['location.citytown.postal_codes', 'm.01_6t1b'],
#               ['location.location.nearby_airports', 'm.04rjc8'],
#               ['travel.travel_destination.tourist_attractions', 'm.0n8yyvt'],
#               ['location.citytown.postal_codes', 'm.01_6t5r'],
#               ['location.location.nearby_airports', 'm.027hrnx'],
#               ['location.citytown.postal_codes', 'm.01_6pxw'],
#               ['location.citytown.postal_codes', 'm.09sh942'],
#               ['location.location.contains', 'm.01_77x6'],
#               ['location.citytown.postal_codes', 'm.07nqmkd'],
#               ['location.citytown.postal_codes', 'm.07nqmgk'],
#               ['travel.travel_destination.tourist_attractions', 'm.021czc'],
#               ['location.citytown.postal_codes', 'm.07nqmfg'],
#               ['location.location.nearby_airports', 'm.01ky66'],
#               ['location.location.contains', 'm.0b0sh'],
#               ['location.citytown.postal_codes', 'm.01_6q1q'],
#               ['location.citytown.postal_codes', 'm.01_6qz6'],
#               ['location.citytown.postal_codes', 'm.01_6zk1'],
#               ['location.location.contains', 'm.0gs227r'],
#               ['location.citytown.postal_codes', 'm.01_78nm'],
#               ['base.biblioness.bibs_location.state', 'm.03v0t'],
#               ['travel.travel_destination.tourist_attractions', 'm.0w7m2x9'],
#               ['location.citytown.postal_codes', 'm.07nqml1'],
#               ['travel.travel_destination.tourist_attractions', 'm.07qbm4'],
#               ['location.citytown.postal_codes', 'm.03dpqpb'],
#               ['location.citytown.postal_codes', 'm.01_6qjr'],
#               ['location.citytown.postal_codes', 'm.01_73_n'],
#               ['location.citytown.postal_codes', 'm.01_72xz'],
#               ['location.citytown.postal_codes', 'm.01_6p_k'],
#               ['location.citytown.postal_codes', 'm.01_6qsj'],
#               ['location.citytown.postal_codes', 'm.01_6t43'],
#               ['location.citytown.postal_codes', 'm.07nqmg3'],
#               ['travel.travel_destination.tourist_attractions', 'm.025v4fb'],
#               ['location.citytown.postal_codes', 'm.01_75zb'],
#               ['location.location.nearby_airports', 'm.01ky66'],
#               ['travel.travel_destination.tourist_attractions', 'm.094154'],
#               ['location.citytown.postal_codes', 'm.07nqmfp'],
#               ['location.location.nearby_airports', 'm.0288msl'],
#               ['travel.travel_destination.tourist_attractions', 'm.05zv09'],
#               ['travel.travel_destination.tourist_attractions', 'm.02rvwrv'],
#               ['location.citytown.postal_codes', 'm.01_6rf1'],
#               ['location.citytown.postal_codes', 'm.01_6v4j'],
#               ['location.citytown.postal_codes', 'm.01_77x6'],
#               ['location.citytown.postal_codes', 'm.01_7gfz'],
#               ['location.citytown.postal_codes', 'm.07nqmlq'],
#               ['location.citytown.postal_codes', 'm.01_78lh'],
#               ['location.citytown.postal_codes', 'm.07nqml8'],
#               ['location.citytown.postal_codes', 'm.01_6v6w'],
#               ['travel.travel_destination.tourist_attractions', 'm.06_7k'],
#               ['travel.travel_destination.tourist_attractions', 'm.0g_8d0'],
#               ['location.citytown.postal_codes', 'm.01_6qcm'],
#               ['location.citytown.postal_codes', 'm.01_6r1z'],
#               ['location.location.nearby_airports', 'm.0288msl'],
#               ['location.citytown.postal_codes', 'm.01_6pvy'],
#               ['location.location.contains', 'm.0d9wz'],
#               ['location.citytown.postal_codes', 'm.01_6pdj'],
#               ['location.location.nearby_airports', 'm.02z431v'],
#               ['location.citytown.postal_codes', 'm.01_6t4y'],
#               ['location.citytown.postal_codes', 'm.07nqmk5'],
#               ['location.citytown.postal_codes', 'm.01_6tgy'],
#               ['location.citytown.postal_codes', 'm.01_6p8l'],
#               ['location.citytown.postal_codes', 'm.01_6q0k'],
#               ['location.location.nearby_airports', 'm.0d4v7r'],
#               ['location.citytown.postal_codes', 'm.01_6q8p'],
#               ['location.citytown.postal_codes', 'm.01_6t5r'],
#               ['location.citytown.postal_codes', 'm.01_6qjr'],
#               ['location.citytown.postal_codes', 'm.07nqmh6'],
#               ['location.citytown.postal_codes', 'm.07nqmjz'],
#               ['location.citytown.postal_codes', 'm.01_6s0l'],
#               ['travel.travel_destination.tourist_attractions', 'm.0j2m3px'],
#               ['location.citytown.postal_codes', 'm.01_6pmb'],
#               ['location.citytown.postal_codes', 'm.07nqmg3'],
#               ['location.citytown.postal_codes', 'm.065rklh'],
#               ['location.citytown.postal_codes', 'm.01_6ps8'],
#               ['location.citytown.postal_codes', 'm.01_6sws'],
#               ['location.citytown.postal_codes', 'm.01_6pgd'],
#               ['location.citytown.postal_codes', 'm.07nqmgb'],
#               ['location.citytown.postal_codes', 'm.07nqmjr'],
#               ['location.citytown.postal_codes', 'm.03dpqpb'],
#               ['location.citytown.postal_codes', 'm.01_6pnb'],
#               ['location.citytown.postal_codes', 'm.01_6t95'],
#               ['location.citytown.postal_codes', 'm.01_6p_k'],
#               ['location.citytown.postal_codes', 'm.01_795b'],
#               ['travel.travel_destination.tourist_attractions', 'm.025v4fb'],
#               ['location.citytown.postal_codes', 'm.01_6r82'],
#               ['location.citytown.postal_codes', 'm.07nqml8'],
#               ['location.citytown.postal_codes', 'm.01_6pdj'],
#               ['travel.travel_destination.tourist_attractions', 'm.02vv_6w'],
#               ['location.citytown.postal_codes', 'm.01_6rfw'],
#               ['location.citytown.postal_codes', 'm.01_6q1q'],
#               ['location.location.nearby_airports', 'm.01l1jx'],
#               ['location.citytown.postal_codes', 'm.01_7gfz'],
#               ['travel.travel_destination.tourist_attractions', 'm.07qbm4'],
#               ['location.citytown.postal_codes', 'm.07nqmly'],
#               ['location.citytown.postal_codes', 'm.07nqmjj'],
#               ['location.citytown.postal_codes', 'm.07nqmgs'],
#               ['location.citytown.postal_codes', 'm.07nqmkv'],
#               ['location.citytown.postal_codes', 'm.07nqms5'],
#               ['location.citytown.postal_codes', 'm.01_6ph7'],
#               ['location.location.contains', 'm.0w7m2x9'],
#               ['travel.travel_destination.tourist_attractions', 'm.04h9qj'],
#               ['location.citytown.postal_codes', 'm.09sh942'],
#               ['location.location.nearby_airports', 'm.026qfyq'],
#               ['location.location.contains', 'm.01_6pxw'],
#               ['location.location.nearby_airports', 'm.027hrnx'],
#               ['location.location.nearby_airports', 'm.01l1jx'],
#               ['location.citytown.postal_codes', 'm.07nqmjr'],
#               ['base.biblioness.bibs_location.state', 'm.03v0t'],
#               ['location.citytown.postal_codes', 'm.07nqmhn'],
#               ['location.citytown.postal_codes', 'm.01_6zk1'],
#               ['location.location.contains', 'm.05zv09'],
#               ['location.citytown.postal_codes', 'm.07nqml1'],
#               ['travel.travel_destination.tourist_attractions', 'm.01dlzc'],
#               ['location.citytown.postal_codes', 'm.01_6q0k'],
#               ['location.citytown.postal_codes', 'm.01_6pvy'],
#               ['location.citytown.postal_codes', 'm.01_6qsj'],
#               ['location.location.contains', 'm.0g_8d0'],
#               ['location.citytown.postal_codes', 'm.07nqmk5'],
#               ['location.citytown.postal_codes', 'm.01_6y3n'],
#               ['location.location.contains', 'm.0b28z'],
#               ['location.citytown.postal_codes', 'm.01_6qcm'],
#               ['location.citytown.postal_codes', 'm.01_6qz6'],
#               ['location.citytown.postal_codes', 'm.01_6p9s'],
#               ['location.citytown.postal_codes', 'm.01_78nm'],
#               ['travel.travel_destination.tourist_attractions', 'm.03y4l3'],
#               ['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.nearby_airports', 'm.026qfyq'],
#               ['travel.travel_destination.tourist_attractions', 'm.0b28z'],
#               ['location.citytown.postal_codes', 'm.01_6rf1'],
#               ['location.citytown.postal_codes', 'm.01_6sws'],
#               ['location.citytown.postal_codes', 'm.07nqmgb'],
#               ['location.citytown.postal_codes', 'm.01_6s0l'],
#               ['location.citytown.postal_codes', 'm.01_78wb'],
#               ['location.location.contains', 'm.01_6v6w'],
#               ['location.citytown.postal_codes', 'm.01_6r78'],
#               ['travel.travel_destination.tourist_attractions', 'm.021czc'],
#               ['location.citytown.postal_codes', 'm.01_6pnb'],
#               ['travel.travel_destination.tourist_attractions', 'm.0n8yyvt'],
#               ['travel.travel_destination.tourist_attractions', 'm.02jw0z'],
#               ['location.citytown.postal_codes', 'm.01_6t43'],
#               ['location.citytown.postal_codes', 'm.01_6qrp'],
#               ['location.citytown.postal_codes', 'm.01_6t4y'],
#               ['travel.travel_destination.tourist_attractions', 'm.0n4_xtw'],
#               ['travel.travel_destination.tourist_attractions', 'm.0b0sh'],
#               ['location.location.contains', 'm.027hqc_'],
#               ['location.citytown.postal_codes', 'm.01_6ph7'],
#               ['travel.travel_destination.tourist_attractions', 'm.027hqc_'],
#               ['location.citytown.postal_codes', 'm.01_6q8p'],
#               ['location.citytown.postal_codes', 'm.07nqmkv'],
#               ['location.citytown.postal_codes', 'm.01_71cx'],
#               ['location.citytown.postal_codes', 'm.07nqmf7'],
#               ['location.citytown.postal_codes', 'm.07nqmfx'],
#               ['location.citytown.postal_codes', 'm.07nqmly'],
#               ['location.citytown.postal_codes', 'm.07nqmhw'],
#               ['travel.travel_destination.tourist_attractions', 'm.0c7ln'],
#               ['location.citytown.postal_codes', 'm.01_6r82'],
#               ['location.citytown.postal_codes', 'm.01_6qp4'],
#               ['travel.travel_destination.tourist_attractions', 'm.0w7m2x9'],
#               ['location.citytown.postal_codes', 'm.01_77x6'],
#               ['travel.travel_destination.tourist_attractions', 'm.05zv09'],
#               ['travel.travel_destination.tourist_attractions', 'm.0bl8mx'],
#               ['location.citytown.postal_codes', 'm.01_6q9q'],
#               ['location.citytown.postal_codes', 'm.07nqmfp'],
#               ['location.citytown.postal_codes', 'm.03dpqrm'],
#               ['location.citytown.postal_codes', 'm.01_7140'],
#               ['location.location.nearby_airports', 'm.02z431v'],
#               ['location.citytown.postal_codes', 'm.07nqmlq'],
#               ['travel.travel_destination.tourist_attractions', 'm.0g_8d0'],
#               ['location.citytown.postal_codes', 'm.07nqmhn'],
#               ['location.citytown.postal_codes', 'm.01_6smy'],
#               ['location.citytown.postal_codes', 'm.07nqmlh'],
#               ['location.citytown.postal_codes', 'm.07nqmjz'],
#               ['location.citytown.postal_codes', 'm.0gs227r'],
#               ['location.citytown.postal_codes', 'm.01_6r78'],
#               ['travel.travel_destination.tourist_attractions', 'm.0d9wz'],
#               ['location.citytown.postal_codes', 'm.01_78wb'],
#               ['location.citytown.postal_codes', 'm.01_6tgy'],
#               ['location.citytown.postal_codes', 'm.01_6p8l'],
#               ['location.citytown.postal_codes', 'm.07nqmjj'],
#               ['travel.travel_destination.tourist_attractions', 'm.02jw0z'],
#               ['location.location.nearby_airports', 'm.08qt9p'],
#               ['location.citytown.postal_codes', 'm.01_6p9s'],
#               ['location.citytown.postal_codes', 'm.03dpqrm'],
#               ['travel.travel_destination.tourist_attractions', 'm.094154'],
#               ['travel.travel_destination.tourist_attractions', 'm.0b28z'],
#               ['location.citytown.postal_codes', 'm.01_77qt'],
#               ['travel.travel_destination.tourist_attractions', 'm.0b0sh'],
#               ['location.citytown.postal_codes', 'm.07nqmf7']],
#              'm.09c7w0': [['base.locations.countries.states_provinces_within',
#                'm.06yxd'],
#               ['location.statistical_region.religions', 'm.03q1lwl'],
#               ['location.statistical_region.religions', 'm.03q1lvq'],
#               ['location.location.contains', 'm.0vzm'],
#               ['location.location.partially_containedby', 'm.059g4'],
#               ['base.aareas.schema.administrative_area.administrative_children',
#                'm.03v0t'],
#               ['base.locations.countries.continent', 'm.059g4'],
#               ['location.country.administrative_divisions', 'm.03v0t'],
#               ['location.location.time_zones', 'm.027wj2_'],
#               ['location.statistical_region.religions', 'm.03q1lvq'],
#               ['location.location.contains', 'm.01_77x6'],
#               ['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.time_zones', 'm.042g7t'],
#               ['location.statistical_region.religions', 'm.03q1lvh'],
#               ['location.location.contains', 'm.02z431v'],
#               ['location.location.contains', 'm.0fv_t'],
#               ['location.country.form_of_government', 'm.01d9r3'],
#               ['location.location.time_zones', 'm.02lcqs'],
#               ['location.location.contains', 'm.01l1jx'],
#               ['location.statistical_region.major_exports', 'm.04g4s8k'],
#               ['location.location.contains', 'm.027hqc_'],
#               ['location.location.time_zones', 'm.02hczc'],
#               ['location.location.contains', 'm.0mmyl'],
#               ['location.country.second_level_divisions', 'm.0mmyl'],
#               ['location.location.time_zones', 'm.02lcrv'],
#               ['base.locations.countries.states_provinces_within', 'm.03v0t'],
#               ['location.statistical_region.religions', 'm.03q1lvy'],
#               ['location.statistical_region.religions', 'm.03q1lvh'],
#               ['base.aareas.schema.administrative_area.administrative_children',
#                'm.07b_l'],
#               ['location.statistical_region.major_exports', 'm.04g4s90'],
#               ['location.location.contains', 'm.03v0t'],
#               ['location.location.time_zones', 'm.027wjl3'],
#               ['location.statistical_region.religions', 'm.03q1lw4'],
#               ['location.country.administrative_divisions', 'm.01_d4'],
#               ['military.military_combatant.military_commanders', 'm.049yn2t'],
#               ['location.statistical_region.religions', 'm.03q1lvy'],
#               ['location.country.form_of_government', 'm.01d9r3'],
#               ['location.country.form_of_government', 'm.0j729'],
#               ['location.country.first_level_divisions', 'm.07b_l'],
#               ['location.location.contains', 'm.01ky66'],
#               ['location.location.time_zones', 'm.02lctm'],
#               ['location.statistical_region.religions', 'm.0_hhjkj'],
#               ['location.country.form_of_government', 'm.0j729'],
#               ['location.location.time_zones', 'm.02fqwt'],
#               ['base.aareas.schema.administrative_area.administrative_children',
#                'm.06yxd'],
#               ['location.country.administrative_divisions', 'm.07b_l'],
#               ['location.location.contains', 'm.09sh942'],
#               ['location.statistical_region.major_imports', 'm.04g4sb5'],
#               ['location.location.contains', 'm.06_7k'],
#               ['location.country.form_of_government', 'm.0c9rw5'],
#               ['location.statistical_region.major_exports', 'm.04g4s8q'],
#               ['location.location.contains', 'm.01_6v6w'],
#               ['location.statistical_region.religions', 'm.03q1lw4'],
#               ['location.location.contains', 'm.0b28z'],
#               ['location.country.form_of_government', 'm.0c9rw5'],
#               ['base.locations.countries.continent', 'm.059g4'],
#               ['location.country.currency_used', 'm.09nqf'],
#               ['location.statistical_region.major_imports', 'm.04g4sbb'],
#               ['location.statistical_region.major_imports', 'm.04g4sbz'],
#               ['location.location.contains', 'm.0gs227r'],
#               ['location.location.time_zones', 'm.02lcrv'],
#               ['location.location.contains', 'm.07b_l'],
#               ['location.statistical_region.major_imports', 'm.04g4sbb'],
#               ['location.country.currency_used', 'm.09nqf'],
#               ['location.statistical_region.major_imports', 'm.04g4sbn'],
#               ['location.location.contains', 'm.06yxd'],
#               ['location.statistical_region.major_imports', 'm.04g4sbt'],
#               ['location.location.contains', 'm.0w7m2x9'],
#               ['location.location.contains', 'm.01_6pxw'],
#               ['location.statistical_region.major_exports', 'm.04g4s8k'],
#               ['location.statistical_region.major_imports', 'm.04g4sb5'],
#               ['location.statistical_region.major_imports', 'm.04g4sbz'],
#               ['location.statistical_region.major_exports', 'm.04g4s8w'],
#               ['location.statistical_region.major_exports', 'm.04g4s8w'],
#               ['location.statistical_region.major_exports', 'm.04g4s90'],
#               ['location.location.time_zones', 'm.042g7t'],
#               ['location.statistical_region.religions', 'm.03q1lwl'],
#               ['location.location.time_zones', 'm.02hcv8'],
#               ['location.country.first_level_divisions', 'm.03v0t'],
#               ['location.country.administrative_divisions', 'm.06yxd'],
#               ['location.statistical_region.major_imports', 'm.04g4sbn'],
#               ['location.location.contains', 'm.02jw0z'],
#               ['location.statistical_region.major_imports', 'm.04g4sbt'],
#               ['location.location.time_zones', 'm.02lcqs'],
#               ['location.statistical_region.major_exports', 'm.04g4s8q'],
#               ['location.country.first_level_divisions', 'm.06yxd'],
#               ['base.locations.countries.states_provinces_within', 'm.07b_l'],
#               ['location.location.time_zones', 'm.02hczc'],
#               ['location.location.time_zones', 'm.02lctm'],
#               ['location.statistical_region.religions', 'm.0_hhjkj'],
#               ['location.location.time_zones', 'm.027wjl3'],
#               ['location.location.contains', 'm.0bx8pn'],
#               ['location.location.time_zones', 'm.027wj2_'],
#               ['location.location.time_zones', 'm.02hcv8'],
#               ['location.location.contains', 'm.01_d4'],
#               ['location.location.primarily_containedby', 'm.059g4']],
#              'm.0fv_t': [['base.biblioness.bibs_location.state', 'm.06yxd'],
#               ['location.location.time_zones', 'm.02hcv8'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['location.location.containedby', 'm.06yxd'],
#               ['base.biblioness.bibs_location.country', 'm.09c7w0']],
#              'm.04yz499': [['military.military_command.military_conflict',
#                'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.01g0dx'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
#               ['military.military_command.military_conflict', 'm.06kd6y'],
#               ['military.military_command.military_conflict', 'm.01hgpt'],
#               ['military.military_command.military_conflict', 'm.06bjm'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.0247w9'],
#               ['military.military_command.military_conflict', 'm.0jnh'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_commander', 'm.034rd'],
#               ['military.military_command.military_conflict', 'm.09r3f']],
#              'm.03v0t': [['location.location.contains', 'm.02jw0z'],
#               ['base.biblioness.bibs_location.country', 'm.09c7w0'],
#               ['location.administrative_division.country', 'm.09c7w0'],
#               ['location.location.contains', 'm.01_d4'],
#               ['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['location.location.contains', 'm.01_6pxw'],
#               ['location.location.contains', 'm.0d9wz'],
#               ['location.location.nearby_airports', 'm.01l1jx'],
#               ['location.location.contains', 'm.01_77x6'],
#               ['location.location.contains', 'm.026qfyq'],
#               ['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.contains', 'm.0w7m2x9'],
#               ['location.location.contains', 'm.021czc'],
#               ['location.administrative_division.first_level_division_of',
#                'm.09c7w0'],
#               ['base.aareas.schema.administrative_area.administrative_parent',
#                'm.09c7w0'],
#               ['base.locations.states_and_provences.country', 'm.09c7w0'],
#               ['location.location.contains', 'm.09sh942'],
#               ['location.location.contains', 'm.01_6v6w'],
#               ['location.location.contains', 'm.0c7ln'],
#               ['location.location.contains', 'm.01dlzc'],
#               ['location.location.contains', 'm.0gs227r']],
#              'm.01zmpg': [['music.artist.genre', 'm.06j6l'],
#               ['people.person.nationality', 'm.09c7w0'],
#               ['music.artist.genre', 'm.021_z5'],
#               ['music.artist.genre', 'm.0ggx5q'],
#               ['people.person.sibling_s', 'm.0652zrb'],
#               ['people.person.religion', 'm.0flw86'],
#               ['music.artist.genre', 'm.064t9']],
#              'm.02srz6': [['music.album.genre', 'm.05bt6j'],
#               ['music.album.genre', 'm.06by7'],
#               ['music.album.genre', 'm.06j6l'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.064t9'],
#               ['music.album.genre', 'm.0ggx5q'],
#               ['music.album.genre', 'm.026z9']],
#              'm.01hl3t4': [['music.album.genre', 'm.0ggx5q'],
#               ['music.album.genre', 'm.064t9'],
#               ['music.album.genre', 'm.06by7'],
#               ['music.album.genre', 'm.06j6l'],
#               ['music.album.genre', 'm.05bt6j'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.021_z5']],
#              'm.04g4sb5': [['location.imports_exports_by_industry.industry',
#                'm.03xm3m'],
#               ['location.imports_exports_by_industry.industry', 'm.03qtd_n'],
#               ['location.imports_exports_by_industry.industry', 'm.0c_jw'],
#               ['location.imports_exports_by_industry.industry', 'm.015smg'],
#               ['location.imports_exports_by_industry.industry', 'm.0c_jw'],
#               ['location.imports_exports_by_industry.industry', 'm.09j2d']],
#              'm.04g36q3': [['education.education.institution', 'm.0bx8pn'],
#               ['education.education.student', 'm.054c1'],
#               ['education.education.institution', 'm.0bx8pn'],
#               ['education.education.major_field_of_study', 'm.07xc_j'],
#               ['education.education.major_field_of_study', 'm.07xc_j'],
#               ['education.education.institution', 'm.07qymj']],
#              'm.0v43grl': [['film.performance.film', 'm.065mvrb'],
#               ['film.performance.film', 'm.0v43grn'],
#               ['film.performance.film', 'm.0djb05y'],
#               ['film.performance.film', 'm.0v435l3'],
#               ['film.performance.film', 'm.036ytw'],
#               ['film.performance.film', 'm.05f5tq'],
#               ['film.performance.actor', 'm.09889g'],
#               ['film.performance.film', 'm.07hqvg'],
#               ['film.performance.film', 'm.0v43grn'],
#               ['film.performance.film', 'm.027fwmt'],
#               ['film.performance.film', 'm.02qsfv'],
#               ['film.performance.film', 'm.031t2d'],
#               ['film.performance.film', 'm.0_cdzjp']],
#              'm.0652zrb': [['people.sibling_relationship.sibling', 'm.09889g'],
#               ['people.sibling_relationship.sibling', 'm.01zmpg'],
#               ['people.sibling_relationship.sibling', 'm.01zmpg'],
#               ['people.sibling_relationship.sibling', 'm.09889g']],
#              'm.09889g': [['music.artist.album', 'm.06308p'],
#               ['film.writer.film', 'm.036ytw'],
#               ['film.actor.film', 'm.0y9dwry'],
#               ['film.actor.film', 'm.0k0tp0'],
#               ['people.person.sibling_s', 'm.09kkmyf'],
#               ['music.artist.album', 'm.02st0w'],
#               ['music.artist.album', 'm.01hl45_'],
#               ['people.person.sibling_s', 'm.0652zrb'],
#               ['music.artist.genre', 'm.064t9'],
#               ['food.diet_follower.follows_diet', 'm.07_lq'],
#               ['music.artist.album', 'm.0q8flcq'],
#               ['music.artist.album', 'm.0vypv96'],
#               ['people.person.children', 'm.0598rm4'],
#               ['music.artist.album', 'm.03jgszc'],
#               ['music.artist.genre', 'm.026z9'],
#               ['film.actor.film', 'm.0ypyc5q'],
#               ['film.actor.film', 'm.0ypycgr'],
#               ['music.artist.album', 'm.0vypv96'],
#               ['people.person.education', 'm.0n1cs5l'],
#               ['music.artist.album', 'm.06308p'],
#               ['music.artist.album', 'm.06_y1fq'],
#               ['medicine.notable_person_with_medical_condition.condition',
#                'm.026k8yn'],
#               ['music.artist.album', 'm.012mtk5b'],
#               ['music.artist.album', 'm.01hl4l8'],
#               ['film.actor.film', 'm.0y9dy_b'],
#               ['music.artist.album', 'm.01hl48b'],
#               ['people.person.sibling_s', 'm.0nf3l7x'],
#               ['music.artist.album', 'm.0q8flcq'],
#               ['people.person.children', 'm.0598rmb'],
#               ['film.actor.film', 'm.0djb8gt'],
#               ['music.artist.album', 'm.01n7xgt'],
#               ['music.artist.album', 'm.0w508xx'],
#               ['music.artist.genre', 'm.026z9'],
#               ['film.actor.film', 'm.0qdng0g'],
#               ['music.artist.album', 'g.11bbxlkxxc'],
#               ['music.artist.album', 'm.0g6_q__'],
#               ['people.person.sibling_s', 'm.0652zrb'],
#               ['music.artist.album', 'm.01hl4hb'],
#               ['music.artist.album', 'm.06_y1fq'],
#               ['film.actor.film', 'm.0v41rbr'],
#               ['music.artist.album', 'm.01hl444'],
#               ['music.artist.genre', 'm.02vjzr'],
#               ['music.artist.album', 'm.02st1p'],
#               ['music.artist.album', 'm.01n7xgt'],
#               ['music.artist.album', 'm.010klcpt'],
#               ['film.actor.film', 'm.0y9dxk3'],
#               ['music.artist.genre', 'm.021_z5'],
#               ['film.actor.film', 'm.0105xc0x'],
#               ['base.danceporn.dancer.music_video', 'm.01hl45_'],
#               ['influence.influence_node.influenced_by', 'm.01lc5'],
#               ['film.music_contributor.film', 'm.036ytw'],
#               ['film.actor.film', 'm.0y9dxk3'],
#               ['music.artist.album', 'm.0jwt60n'],
#               ['people.deceased_person.cause_of_death', 'm.0gg4h'],
#               ['film.actor.film', 'm.0105xc0x'],
#               ['people.person.children', 'm.0598rmb'],
#               ['music.artist.album', 'm.096y7s'],
#               ['film.film_story_contributor.film_story_credits', 'm.07hqvg'],
#               ['music.artist.album', 'g.1236srvy'],
#               ['music.artist.album', 'm.0y4qyrn'],
#               ['music.artist.genre', 'm.06j6l'],
#               ['film.actor.film', 'm.0v41rbr'],
#               ['people.person.education', 'm.0n1cs5l'],
#               ['music.artist.album', 'g.1236srvy'],
#               ['people.person.sibling_s', 'm.0652zr5'],
#               ['music.artist.album', 'm.01hl3t4'],
#               ['music.artist.album', 'm.02srz6'],
#               ['music.artist.genre', 'm.06j6l'],
#               ['music.artist.album', 'm.0132tgw6'],
#               ['music.artist.album', 'm.01hl2j6'],
#               ['music.artist.genre', 'm.02vjzr'],
#               ['influence.influence_node.influenced_by', 'm.04ct6p'],
#               ['music.artist.album', 'm.047qwf7'],
#               ['film.actor.film', 'm.0y9dy_b'],
#               ['influence.influence_node.influenced_by', 'm.081nh'],
#               ['film.actor.film', 'm.0qdng0g'],
#               ['people.person.sibling_s', 'm.09kkmyr'],
#               ['music.artist.album', 'm.01k9bm5'],
#               ['film.actor.film', 'm.0djb8gt'],
#               ['music.artist.album', 'm.01hl40t'],
#               ['music.artist.album', 'm.0132tgw6'],
#               ['music.artist.album', 'm.01hl3t4'],
#               ['music.artist.genre', 'm.06by7'],
#               ['music.artist.album', 'm.01hl40t'],
#               ['film.actor.film', 'm.0k0tp0'],
#               ['people.person.nationality', 'm.09c7w0'],
#               ['film.actor.film', 'm.0y9dwry'],
#               ['film.actor.film', 'm.02vdbk8'],
#               ['music.artist.album', 'm.06w81qp'],
#               ['influence.influence_node.influenced_by', 'm.01lc5'],
#               ['music.artist.album', 'm.01hl3jm'],
#               ['people.person.sibling_s', 'm.0652zr5'],
#               ['film.actor.film', 'm.0ypycgr'],
#               ['influence.influence_node.influenced_by', 'm.04ct6p'],
#               ['people.person.sibling_s', 'm.0nf3l7x'],
#               ['film.actor.film', 'm.0ypyc5q'],
#               ['music.artist.genre', 'm.05bt6j'],
#               ['music.artist.album', 'm.01hl3jm'],
#               ['food.diet_follower.follows_diet', 'm.07_lq'],
#               ['music.artist.album', 'g.11bbxlkxxc'],
#               ['music.artist.album', 'm.0jwt60n'],
#               ['film.actor.film', 'm.0v435l1'],
#               ['music.artist.album', 'm.03jgszc'],
#               ['music.artist.genre', 'm.02lkt'],
#               ['music.artist.genre', 'm.0ggx5q'],
#               ['influence.influence_node.influenced_by', 'm.081nh'],
#               ['music.artist.genre', 'm.06by7'],
#               ['influence.influence_node.influenced_by', 'm.01b9db'],
#               ['people.person.children', 'm.0598rm4'],
#               ['film.actor.film', 'm.0y9dy4w'],
#               ['music.artist.album', 'm.03jg4tt'],
#               ['architecture.architectural_structure_owner.structures_owned',
#                'm.0j17fx_'],
#               ['music.artist.album', 'm.01hl48b'],
#               ['music.artist.album', 'm.012mtk5b'],
#               ['people.deceased_person.cause_of_death', 'm.0gg4h'],
#               ['film.actor.film', 'm.0ngxnpl'],
#               ['music.artist.album', 'm.02st1p'],
#               ['music.artist.album', 'm.01hl4l8'],
#               ['music.artist.genre', 'm.064t9'],
#               ['music.artist.album', 'm.03jg4tt'],
#               ['music.artist.album', 'm.01hl2j6'],
#               ['film.actor.film', 'm.0ngxnpl'],
#               ['music.artist.album', 'm.047qwf7'],
#               ['film.actor.film', 'm.0v43grl'],
#               ['people.person.children', 'm.065qbyj'],
#               ['influence.influence_node.influenced_by', 'm.0407f'],
#               ['film.actor.film', 'm.0v43grl'],
#               ['people.person.sibling_s', 'm.09kkmyf'],
#               ['music.artist.genre', 'm.021_z5'],
#               ['film.producer.films_executive_produced', 'm.036ytw'],
#               ['people.person.children', 'm.065qbyj'],
#               ['music.artist.album', 'm.010klcpt'],
#               ['film.actor.film', 'm.0v435l1'],
#               ['music.artist.album', 'm.0y4qyrn'],
#               ['medicine.notable_person_with_medical_condition.condition',
#                'm.026k8yn'],
#               ['music.composer.compositions', 'm.01hl45_'],
#               ['music.artist.album', 'm.06w81qp'],
#               ['influence.influence_node.influenced_by', 'm.01b9db'],
#               ['music.artist.album', 'm.01hl4hb'],
#               ['people.person.sibling_s', 'm.09kkmyr'],
#               ['music.artist.genre', 'm.05bt6j'],
#               ['music.artist.genre', 'm.02lkt'],
#               ['music.artist.album', 'm.096y7s'],
#               ['film.actor.film', 'm.02vdbk8'],
#               ['music.artist.genre', 'm.0ggx5q'],
#               ['music.artist.album', 'm.0g6_q__'],
#               ['film.actor.film', 'm.0y9dy4w'],
#               ['music.artist.album', 'm.01hl45_'],
#               ['music.artist.album', 'm.02srz6'],
#               ['music.artist.album', 'm.02st0w'],
#               ['music.artist.album', 'm.01k9bm5'],
#               ['architecture.architectural_structure_owner.structures_owned',
#                'm.0j17fx_'],
#               ['film.music_contributor.film', 'm.07hqvg'],
#               ['music.artist.album', 'm.01hl444'],
#               ['influence.influence_node.influenced_by', 'm.0407f'],
#               ['music.artist.album', 'm.0w508xx']],
#              'm.09hxlzp': [['military.military_command.military_conflict',
#                'm.06bjm'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_conflict', 'm.06kd6y'],
#               ['military.military_command.military_conflict', 'm.0247w9'],
#               ['military.military_command.military_conflict', 'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.01hgpt'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.09r3f'],
#               ['military.military_command.military_commander', 'm.034rd'],
#               ['military.military_command.military_conflict', 'm.0jnh'],
#               ['military.military_command.military_conflict', 'm.01g0dx'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.09r3f']],
#              'm.04yxtkk': [['military.military_command.military_conflict',
#                'm.01hgpt'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
#               ['military.military_command.military_conflict', 'm.06kd6y'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.06bjm'],
#               ['military.military_command.military_conflict', 'm.01g0dx'],
#               ['military.military_command.military_conflict', 'm.09r3f'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.0247w9'],
#               ['military.military_command.military_conflict', 'm.06kd6y'],
#               ['military.military_command.military_commander', 'm.034rd'],
#               ['military.military_command.military_conflict', 'm.0jnh']],
#              'm.04g4sbz': [['location.imports_exports_by_industry.industry',
#                'm.0c_jw'],
#               ['location.imports_exports_by_industry.industry', 'm.015smg'],
#               ['location.imports_exports_by_industry.industry', 'm.09j2d'],
#               ['location.imports_exports_by_industry.industry', 'm.03xm3m'],
#               ['location.imports_exports_by_industry.industry', 'm.03qtd_n'],
#               ['location.imports_exports_by_industry.industry', 'm.09j2d']],
#              'm.064t9': [['media_common.netflix_genre.titles', 'm.036ytw'],
#               ['music.genre.albums', 'm.0jwt60n'],
#               ['music.genre.parent_genre', 'm.06by7'],
#               ['music.genre.albums', 'm.06308p'],
#               ['music.genre.parent_genre', 'm.06j6l'],
#               ['music.genre.albums', 'm.01hl444'],
#               ['music.genre.albums', 'm.02st1p'],
#               ['music.genre.albums', 'm.01hl40t'],
#               ['music.genre.albums', 'm.01hl3t4'],
#               ['music.genre.albums', 'm.03jgszc'],
#               ['music.genre.albums', 'm.096y7s'],
#               ['music.genre.parent_genre', 'm.0ggx5q'],
#               ['music.genre.albums', 'm.03jg4tt'],
#               ['music.genre.albums', 'm.02srz6'],
#               ['music.genre.artists', 'm.09889g'],
#               ['music.genre.albums', 'm.01hl3jm'],
#               ['music.genre.albums', 'm.06_y1fq'],
#               ['music.genre.albums', 'm.01hl4hb'],
#               ['music.genre.albums', 'g.11bbxlkxxc'],
#               ['music.genre.albums', 'm.01k9bm5'],
#               ['music.genre.albums', 'm.047qwf7'],
#               ['music.genre.artists', 'm.0407f'],
#               ['music.genre.artists', 'm.01zmpg'],
#               ['music.genre.albums', 'm.06w81qp'],
#               ['music.genre.albums', 'm.02st0w']],
#              'm.0v41rbr': [['film.performance.film', 'm.0_cdzjp'],
#               ['film.performance.film', 'm.0djb05y'],
#               ['film.performance.film', 'm.065mvrb'],
#               ['film.performance.film', 'm.02qsfv'],
#               ['film.performance.film', 'm.027fwmt'],
#               ['film.performance.film', 'm.031t2d'],
#               ['film.performance.film', 'm.07hqvg'],
#               ['film.performance.film', 'm.036ytw'],
#               ['film.performance.film', 'm.07hqvg'],
#               ['film.performance.film', 'm.0v43grn'],
#               ['film.performance.film', 'm.0v435l3'],
#               ['film.performance.actor', 'm.09889g'],
#               ['film.performance.film', 'm.05f5tq']],
#              'm.0vzm': [['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['base.biblioness.bibs_location.state', 'm.07b_l'],
#               ['base.biblioness.bibs_location.country', 'm.09c7w0'],
#               ['location.location.containedby', 'm.07b_l']],
#              'm.05bt6j': [['music.genre.albums', 'm.02st0w'],
#               ['music.genre.albums', 'm.02srz6'],
#               ['music.genre.albums', 'm.096y7s'],
#               ['music.genre.albums', 'g.11bbxlkxxc'],
#               ['music.genre.artists', 'm.09889g'],
#               ['music.genre.parent_genre', 'm.06by7'],
#               ['music.genre.albums', 'm.02st1p'],
#               ['music.genre.albums', 'm.01hl3t4'],
#               ['music.genre.albums', 'm.01hl3jm'],
#               ['music.genre.albums', 'm.03jgszc'],
#               ['music.genre.albums', 'm.01hl4hb']],
#              'm.027hqc_': [['dataworld.gardening_hint.split_to', 'm.02rvwrv'],
#               ['travel.tourist_attraction.near_travel_destination', 'm.01_d4'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['location.location.containedby', 'm.01_d4']],
#              'm.0djb8gt': [['film.performance.film', 'm.027fwmt'],
#               ['film.performance.film', 'm.0_cdzjp'],
#               ['film.performance.film', 'm.07hqvg'],
#               ['film.performance.film', 'm.065mvrb'],
#               ['film.performance.film', 'm.05f5tq'],
#               ['film.performance.film', 'm.02qsfv'],
#               ['film.performance.film', 'm.0djb05y'],
#               ['film.performance.film', 'm.0v43grn'],
#               ['film.performance.film', 'm.0v435l3'],
#               ['film.performance.actor', 'm.09889g'],
#               ['film.performance.film', 'm.0djb05y'],
#               ['film.performance.film', 'm.031t2d'],
#               ['film.performance.film', 'm.036ytw']],
#              'm.0w7m2x9': [['location.location.containedby', 'm.01_d4'],
#               ['location.location.containedby', 'm.03v0t'],
#               ['travel.tourist_attraction.near_travel_destination', 'm.01_d4'],
#               ['location.location.containedby', 'm.09c7w0'],
#               ['religion.place_of_worship.religion', 'm.0flw86']],
#              'm.0542n': [['medicine.disease.notable_people_with_this_condition',
#                'm.034rd']],
#              'm.04yv_x3': [['military.military_command.military_conflict',
#                'm.06kd6y'],
#               ['military.military_command.military_conflict', 'm.0247w9'],
#               ['military.military_command.military_conflict', 'm.06bjm'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_conflict', 'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_commander', 'm.034rd'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
#               ['military.military_command.military_conflict', 'm.0jnh'],
#               ['military.military_command.military_conflict', 'm.01hgpt'],
#               ['military.military_command.military_conflict', 'm.09r3f'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.01g0dx']],
#              'm.01hl40t': [['music.album.genre', 'm.06j6l'],
#               ['music.album.genre', 'm.0ggx5q'],
#               ['music.album.genre', 'm.064t9'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.06by7'],
#               ['music.album.genre', 'm.026z9']],
#              'm.03jgszc': [['music.album.genre', 'm.06by7'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.064t9'],
#               ['music.album.genre', 'm.021_z5'],
#               ['music.album.genre', 'm.05bt6j'],
#               ['music.album.genre', 'm.06j6l'],
#               ['music.album.genre', 'm.0ggx5q']],
#              'm.01_6pp5': [['location.postal_code.country', 'm.09c7w0']],
#              'm.031t2d': [['film.film.starring', 'm.0ngxnpl'],
#               ['film.film.country', 'm.09c7w0']],
#              'm.04yv_tf': [['military.military_command.military_conflict',
#                'm.0b364c'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.06kd6y'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
# ...
#               ['location.imports_exports_by_industry.industry', 'm.03q9wp2'],
#               ['location.imports_exports_by_industry.industry', 'm.015smg']],
#              'm.0g_8d0': [['location.location.containedby', 'm.01_d4'],
#               ['travel.tourist_attraction.near_travel_destination', 'm.01_d4'],
#               ['location.location.containedby', 'm.01_6pdj']],
#              'm.0ypycgr': [['film.performance.film', 'm.07hqvg'],
#               ['film.performance.film', 'm.0v435l3'],
#               ['film.performance.film', 'm.065mvrb'],
#               ['film.performance.film', 'm.0_cdzjp'],
#               ['film.performance.film', 'm.02qsfv'],
#               ['film.performance.film', 'm.036ytw'],
#               ['film.performance.film', 'm.065mvrb'],
#               ['film.performance.actor', 'm.09889g'],
#               ['film.performance.film', 'm.031t2d'],
#               ['film.performance.film', 'm.05f5tq'],
#               ['film.performance.film', 'm.0v43grn'],
#               ['film.performance.film', 'm.027fwmt'],
#               ['film.performance.film', 'm.0djb05y']],
#              'm.04yykw2': [['military.military_command.military_conflict',
#                'm.01hgpt'],
#               ['military.military_command.military_conflict', 'm.0jnh'],
#               ['military.military_command.military_conflict', 'm.0247w9'],
#               ['military.military_command.military_conflict', 'm.014pd3'],
#               ['military.military_command.military_conflict', 'm.01g0dx'],
#               ['military.military_command.military_conflict', 'm.02g1n3'],
#               ['military.military_command.military_conflict', 'm.09r3f'],
#               ['military.military_command.military_conflict', 'm.0b364c'],
#               ['military.military_command.military_commander', 'm.034rd'],
#               ['military.military_command.military_conflict', 'm.02fmsl'],
#               ['military.military_command.military_conflict', 'm.06bjm'],
#               ['military.military_command.military_conflict', 'm.07h0q2'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_conflict', 'm.08knpp'],
#               ['military.military_command.military_conflict', 'm.06kd6y']],
#              'm.01d9r3': [['government.form_of_government.countries',
#                'm.09c7w0']],
#              'm.0_hhjkj': [['location.religion_percentage.religion',
#                'm.092bf5'],
#               ['location.religion_percentage.religion', 'm.01lp8'],
#               ['location.religion_percentage.religion', 'm.03_gx'],
#               ['location.religion_percentage.religion', 'm.0kpl'],
#               ['location.religion_percentage.religion', 'm.0flw86'],
#               ['location.religion_percentage.religion', 'm.03j6c'],
#               ['location.religion_percentage.religion', 'm.0kpl']],
#              'm.01b9db': [['influence.influence_node.influenced', 'm.04ct6p'],
#               ['people.person.nationality', 'm.09c7w0'],
#               ['influence.influence_node.influenced', 'm.09889g'],
#               ['influence.influence_node.influenced_by', 'm.01lc5']],
#              'm.0v43grn': [['film.film.starring', 'm.0v43grl']],
#              'm.01_6p6k': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmh6': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0nf3l7x': [['people.sibling_relationship.sibling', 'm.09889g'],
#               ['people.sibling_relationship.sibling', 'm.09889g'],
#               ['people.sibling_relationship.sibling', 'm.01zmpg']],
#              'm.05f5tq': [['film.film.starring', 'm.0ypyc5q'],
#               ['film.film.country', 'm.09c7w0']],
#              'm.01_6q9q': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01hl2j6': [['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.06j6l']],
#              'm.0_cdzjp': [['film.film.starring', 'm.0105xc0x']],
#              'm.01_78lh': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07_lq': [['food.diet.followers', 'm.09889g']],
#              'm.01k9bm5': [['music.soundtrack.film', 'm.027fwmt'],
#               ['music.album.genre', 'm.06j6l'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.026z9'],
#               ['music.album.genre', 'm.064t9']],
#              'm.07nqmj2': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0g6_q__': [['music.album.artist', 'm.09889g']],
#              'm.01_75zb': [['location.postal_code.country', 'm.09c7w0']],
#              'm.02qsfv': [['film.film.starring', 'm.0qdng0g'],
#               ['film.film.sequel', 'm.036ytw'],
#               ['film.film.country', 'm.09c7w0']],
#              'm.09nqf': [['base.coinsdaily.coin_type.country', 'm.09c7w0'],
#               ['finance.currency.countries_used', 'm.09c7w0']],
#              'm.0vypv96': [['music.album.artist', 'm.09889g']],
#              'm.01_6qsj': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0jwt60n': [['music.album.genre', 'm.064t9'],
#               ['music.album.genre', 'm.0ggx5q'],
#               ['music.album.genre', 'm.06j6l'],
#               ['music.album.artist', 'm.09889g'],
#               ['music.album.genre', 'm.06by7']],
#              'm.07nqmf7': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6qrp': [['location.postal_code.country', 'm.09c7w0']],
#              'm.042g7t': [['time.time_zone.locations_in_this_time_zone',
#                'm.059g4'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.09c7w0']],
#              'm.01g0dx': [['base.culturalevent.event.entity_involved',
#                'm.034rd'],
#               ['time.event.included_in_event', 'm.02fmsl'],
#               ['time.event.included_in_event', 'm.0jnh'],
#               ['military.military_conflict.commanders', 'm.049yn2t']],
#              'm.07nqmly': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0n4_xtw': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.01_6v6w': [['location.location.containedby', 'm.09c7w0'],
#               ['location.postal_code.country', 'm.09c7w0'],
#               ['location.location.contains', 'm.0gs227r'],
#               ['location.location.containedby', 'm.01_d4'],
#               ['location.location.contains', 'm.0bl8mx'],
#               ['location.location.containedby', 'm.03v0t']],
#              'm.01_6t1b': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6qcm': [['location.postal_code.country', 'm.09c7w0']],
#              'm.027hrnx': [['aviation.airport.serves', 'm.01_d4']],
#              'm.0b0sh': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4'],
#               ['location.location.containedby', 'm.01_d4']],
#              'm.01_6ph7': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmjj': [['location.postal_code.country', 'm.09c7w0']],
#              'm.021czc': [['location.location.time_zones', 'm.02fqwt'],
#               ['location.location.containedby', 'm.01_d4'],
#               ['location.location.containedby', 'm.03v0t'],
#               ['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.0598rm4': [['people.person.parents', 'm.09889g'],
#               ['people.person.nationality', 'm.09c7w0']],
#              'm.01hl48b': [['music.album.artist', 'm.09889g']],
#              'm.05zv09': [['location.location.containedby', 'm.01_d4'],
#               ['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.02g1n3': [['military.military_conflict.commanders',
#                'm.04yv_x3'],
#               ['base.culturalevent.event.entity_involved', 'm.034rd'],
#               ['time.event.included_in_event', 'm.0jnh']],
#              'm.07nqmjz': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmg_': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0c7ln': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4'],
#               ['location.location.containedby', 'm.01_d4'],
#               ['location.location.containedby', 'm.03v0t']],
#              'm.02hcv8': [['time.time_zone.locations_in_this_time_zone',
#                'm.0fv_t'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.06yxd'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.0mmyl'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.059g4'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.09c7w0']],
#              'm.0djb05y': [['film.film.starring', 'm.0djb8gt'],
#               ['film.film.country', 'm.09c7w0']],
#              'm.01_6t4y': [['location.postal_code.country', 'm.09c7w0']],
#              'm.02lctm': [['time.time_zone.locations_in_this_time_zone',
#                'm.09c7w0'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.059g4']],
#              'm.01_6t5r': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqms5': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0gg4h': [['people.cause_of_death.people', 'm.09889g']],
#              'm.0q8flcq': [['music.album.artist', 'm.09889g']],
#              'm.027wjl3': [['time.time_zone.locations_in_this_time_zone',
#                'm.09c7w0']],
#              'm.08qt9p': [['aviation.airport.serves', 'm.01_d4']],
#              'm.02vlwj': [['architecture.structure.owner', 'm.0j17fx_']],
#              'm.02rvwrv': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4'],
#               ['location.location.containedby', 'm.01_d4']],
#              'm.01_6tgy': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6rf1': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6pnb': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07qymj': [['education.educational_institution.students_graduates',
#                'm.0jwk2zd']],
#              'm.07nqmj9': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01ky66': [['location.location.containedby', 'm.01_d4'],
#               ['aviation.airport.serves', 'm.01_d4'],
#               ['location.location.containedby', 'm.09c7w0']],
#              'm.07nqml1': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmlh': [['location.postal_code.country', 'm.09c7w0']],
#              'm.065mvrb': [['film.film.starring', 'm.0ypycgr'],
#               ['film.film.country', 'm.09c7w0']],
#              'm.01_6p8l': [['location.postal_code.country', 'm.09c7w0']],
#              'm.06lhpy': [['education.educational_institution.students_graduates',
#                'm.0n1cs5l']],
#              'm.01_6pgd': [['location.postal_code.country', 'm.09c7w0'],
#               ['location.location.contains', 'm.02vv_6w']],
#              'm.01lp8': [['religion.religion.branched_from', 'm.03_gx']],
#              'm.04h9qj': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.01_6s_6': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmgs': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmhn': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmfx': [['location.postal_code.country', 'm.09c7w0']],
#              'm.06_7k': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4'],
#               ['location.location.containedby', 'm.01_d4'],
#               ['location.location.containedby', 'm.09c7w0']],
#              'm.06jncs': [['sports.sports_league_draft.picks', 'm.02h7cgv']],
#              'm.01_6t43': [['location.postal_code.country', 'm.09c7w0']],
#              'm.02lcqs': [['time.time_zone.locations_in_this_time_zone',
#                'm.059g4'],
#               ['time.time_zone.locations_in_this_time_zone', 'm.09c7w0']],
#              'm.07nqmkm': [['location.postal_code.country', 'm.09c7w0']],
#              'm.03y4l3': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.07jwr': [['medicine.disease.notable_people_with_this_condition',
#                'm.034rd']],
#              'm.0n1cs5l': [['education.education.institution', 'm.06lhpy'],
#               ['education.education.student', 'm.09889g'],
#               ['education.education.institution', 'm.06lhpy']],
#              'm.0288msl': [['aviation.airport.serves', 'm.01_d4']],
#              'm.01_6r78': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_7140': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmfg': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6pmb': [['location.postal_code.country', 'm.09c7w0']],
#              'm.06vr2': [['medicine.disease.notable_people_with_this_condition',
#                'm.034rd']],
#              'm.01_6zk1': [['location.postal_code.country', 'm.09c7w0']],
#              'm.03dpqpb': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0c9rw5': [['government.form_of_government.countries',
#                'm.09c7w0']],
#              'm.02vv_6w': [['location.location.containedby', 'm.01_6pgd'],
#               ['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.07nqmgk': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqmgb': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6pdj': [['location.location.contains', 'm.0g_8d0'],
#               ['location.postal_code.country', 'm.09c7w0']],
#              'm.0v435l3': [['film.film.starring', 'm.0v435l1']],
#              'm.01_77qt': [['location.postal_code.country', 'm.09c7w0']],
#              'm.026k8yn': [['medicine.disease.notable_people_with_this_condition',
#                'm.09889g']],
#              'm.07nqmhf': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6rfw': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01n7xgt': [['music.album.artist', 'm.09889g']],
#              'm.01_72xz': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07qbm4': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.01hl4l8': [['music.album.artist', 'm.09889g']],
#              'm.07nqmjr': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0d4v7r': [['aviation.airport.serves', 'm.01_d4']],
#              'm.01_71cx': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0132tgw6': [['music.album.artist', 'm.09889g']],
#              'm.01_6qp4': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6p_k': [['location.postal_code.country', 'm.09c7w0']],
#              'm.07nqml8': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0n8yyvt': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.01_6q8p': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6s0l': [['location.postal_code.country', 'm.09c7w0']],
#              'm.09kkmyr': [['people.sibling_relationship.sibling', 'm.09889g'],
#               ['people.sibling_relationship.sibling', 'm.09889g'],
#               ['people.sibling_relationship.sibling', 'm.01zmpg']],
#              'm.094154': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.01_6y3n': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6v4j': [['location.postal_code.country', 'm.09c7w0']],
#              'g.1236srvy': [['music.album.artist', 'm.09889g']],
#              'm.01_7gfz': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0j729': [['government.form_of_government.countries',
#                'm.09c7w0']],
#              'm.01_6q1q': [['location.postal_code.country', 'm.09c7w0']],
#              'm.0j2m3px': [['travel.tourist_attraction.near_travel_destination',
#                'm.01_d4']],
#              'm.07nqmhw': [['location.postal_code.country', 'm.09c7w0']],
#              'm.01_6q0k': [['location.postal_code.country', 'm.09c7w0']]})

# %%
queries = load_queries()
queries
# Out:
# [[1,
#   'what time zones are there in the us',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.location.time_zones', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.027wj2_',
#     'EntityName': 'Samoa Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.027wjl3',
#     'EntityName': 'Chamorro Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fqwt',
#     'EntityName': 'Central Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02hcv8',
#     'EntityName': 'Eastern Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02hczc',
#     'EntityName': 'Mountain Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02lcqs',
#     'EntityName': 'Pacific Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02lcrv',
#     'EntityName': 'Alaska Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02lctm',
#     'EntityName': 'Hawaii-Aleutian Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.042g7t',
#     'EntityName': 'Atlantic Time Zone'}]],
#  [2,
#   'what are major exports of the usa',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.statistical_region.major_exports', '?y'],
#    ['?y', 'ns:location.imports_exports_by_industry.industry', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.015smg',
#     'EntityName': 'Automotive industry'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03q9wp2',
#     'EntityName': 'Food Manufacturing'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03qtd_n',
#     'EntityName': 'Pharmaceutical Preparation'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03qtf10',
#     'EntityName': 'Industrial Organic Chemicals, NEC'}]],
#  [3,
#   'what time is right now in texas',
#   'm.07b_l',
#   [['ns:m.07b_l', 'ns:location.location.time_zones', '?x']],
#   'Texas',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fqwt',
#     'EntityName': 'Central Time Zone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02hczc',
#     'EntityName': 'Mountain Time Zone'}]],
#  [4,
#   'what war was george washington associated with',
#   'm.034rd',
#   [['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y'],
#    ['?y', 'ns:military.military_command.military_conflict', '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.014pd3',
#     'EntityName': 'Battle of Brandywine'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.014s1b',
#     'EntityName': 'Siege of Yorktown'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01bh42',
#     'EntityName': 'Treaty of Alliance'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01g09p',
#     'EntityName': 'Battle of Long Island'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01g0dx',
#     'EntityName': 'Battle of Princeton'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01gphc',
#     'EntityName': 'Braddock Expedition'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hgpt',
#     'EntityName': 'Battle of Trenton'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01jnys',
#     'EntityName': 'Siege of Boston'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01k0s4',
#     'EntityName': 'Battle of Monmouth'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.020_gf',
#     'EntityName': 'Battle of Germantown'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0247w9',
#     'EntityName': 'Battle of White Plains'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fmsl',
#     'EntityName': 'New York and New Jersey campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fnwp',
#     'EntityName': 'Battle of Harlem Heights'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02g1n3',
#     'EntityName': "Landing at Kip's Bay"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02pjz77',
#     'EntityName': 'Battle of the Clouds'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04m2k9',
#     'EntityName': "Battle of Pell's Point"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05b6mx0',
#     'EntityName': 'Battle of the Monongahela'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05f78h',
#     'EntityName': 'Battle of Fort Necessity'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.062pq1',
#     'EntityName': 'Boston campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.066xwk',
#     'EntityName': 'Battle of Jumonville Glen'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06bjm',
#     'EntityName': 'Quasi-War'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06kd6y',
#     'EntityName': 'Battle of Fort Duquesne'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07h0q2',
#     'EntityName': 'Battle of the Assunpink Creek'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.08knpp',
#     'EntityName': 'Fortification of Dorchester Heights'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09r3f',
#     'EntityName': 'French and Indian War'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0b364c',
#     'EntityName': 'Battle of Fort Washington'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0bxl0n',
#     'EntityName': 'Philadelphia campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0drwsm9',
#     'EntityName': 'Yorktown campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h42fq',
#     'EntityName': 'Battle of White Marsh'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0jnh',
#     'EntityName': 'American Revolutionary War'}]],
#  [5,
#   'what are the most common religions in the united states',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.statistical_region.religions', '?y'],
#    ['?y', 'ns:location.religion_percentage.religion', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01lp8',
#     'EntityName': 'Christianity'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03_gx',
#     'EntityName': 'Judaism'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03j6c',
#     'EntityName': 'Hinduism'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07w8f',
#     'EntityName': 'Unitarian Universalism'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.092bf5',
#     'EntityName': 'Buddhism'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0flw86',
#     'EntityName': 'Islam'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0kpl',
#     'EntityName': 'Atheism'}]],
#  [6,
#   'what are the names of michael jackson children',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:people.person.children', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0598rm4',
#     'EntityName': 'Paris-Michael Katherine Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0598rmb',
#     'EntityName': 'Michael Joseph Jackson, Jr.'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.065qbyj',
#     'EntityName': 'Prince Michael Jackson II'}]],
#  [7,
#   'when michael jordan got drafted',
#   'm.054c1',
#   [['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y'],
#    ['?y', 'ns:sports.sports_league_draft_pick.draft', '?x']],
#   'Michael Jordan',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06jncs',
#     'EntityName': '1984 NBA draft'}]],
#  [8,
#   'what type of government and economic system does the united states have',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]],
#  [9,
#   'what country was george washington from',
#   'm.034rd',
#   [['ns:m.034rd', 'ns:people.person.nationality', '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02p89zz',
#     'EntityName': 'British America'}]],
#  [10,
#   'what are the major imports of the united states',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.statistical_region.major_imports', '?y'],
#    ['?y', 'ns:location.imports_exports_by_industry.industry', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.015smg',
#     'EntityName': 'Automotive industry'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03qtd_n',
#     'EntityName': 'Pharmaceutical Preparation'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03xm3m',
#     'EntityName': 'Petroleum industry'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09j2d',
#     'EntityName': 'Clothing'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c_jw',
#     'EntityName': 'Furniture'}]],
#  [11,
#   'on which continent is the usa located',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:base.locations.countries.continent', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.059g4',
#     'EntityName': 'North America'}]],
#  [12,
#   'what continent is the usa located in',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:base.locations.countries.continent', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.059g4',
#     'EntityName': 'North America'}]],
#  [13,
#   'what are the airports in chicago',
#   'm.01_d4',
#   [['ns:m.01_d4', 'ns:location.location.nearby_airports', '?x']],
#   'Chicago',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01ky66',
#     'EntityName': "O'Hare International Airport"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01l1jx',
#     'EntityName': 'Chicago Midway International Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.026qfyq',
#     'EntityName': 'Aurora Municipal Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.027hrnx',
#     'EntityName': 'Lansing Municipal Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0288msl',
#     'EntityName': 'Schaumburg Regional Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02z431v',
#     'EntityName': 'Waukegan Regional Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04rjc8',
#     'EntityName': 'Gary/Chicago International Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.08qt9p',
#     'EntityName': 'Chicago Executive Airport'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0d4v7r',
#     'EntityName': 'Lewis University Airport'}]],
#  [14,
#   'what are the names of michael jackson movies',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:film.actor.film', '?y'],
#    ['?y', 'ns:film.performance.film', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0_cdzjp',
#     'EntityName': 'Michael Jackson Unmasked'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.027fwmt',
#     'EntityName': 'The Wiz'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02qsfv',
#     'EntityName': 'Captain EO'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.031t2d',
#     'EntityName': 'Men in Black II'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.036ytw',
#     'EntityName': 'Moonwalker'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05f5tq',
#     'EntityName': 'Motown 25: Yesterday, Today, Forever'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.065mvrb',
#     'EntityName': 'Free to Be… You and Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07hqvg',
#     'EntityName': "Michael Jackson's Ghosts"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0djb05y',
#     'EntityName': 'Miss Cast Away'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v435l3',
#     'EntityName': 'Captain EO Promo & Pre-show'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v43grn',
#     'EntityName': 'Wiz on Down the Road'}]],
#  [15,
#   'what timezone is illinois on',
#   'm.03v0t',
#   [['ns:m.03v0t', 'ns:location.location.time_zones', '?x']],
#   'Illinois',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fqwt',
#     'EntityName': 'Central Time Zone'}]],
#  [16,
#   'what year michael jordan came in the nba',
#   'm.054c1',
#   [['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y'],
#    ['?y', 'ns:sports.sports_league_draft_pick.draft', '?x']],
#   'Michael Jordan',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06jncs',
#     'EntityName': '1984 NBA draft'}]],
#  [17,
#   'what is the political system of the us',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]],
#  [18,
#   'what illnesses did george washington have',
#   'm.034rd',
#   [['ns:m.034rd',
#     'ns:medicine.notable_person_with_medical_condition.condition',
#     '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0542n',
#     'EntityName': 'Malaria'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06vr2',
#     'EntityName': 'Smallpox'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07jwr',
#     'EntityName': 'Tuberculosis'}]],
#  [19,
#   'what illnesses did george washington suffer from',
#   'm.034rd',
#   [['ns:m.034rd',
#     'ns:medicine.notable_person_with_medical_condition.condition',
#     '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0542n',
#     'EntityName': 'Malaria'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06vr2',
#     'EntityName': 'Smallpox'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07jwr',
#     'EntityName': 'Tuberculosis'}]],
#  [20,
#   'where is south carolina located',
#   'm.06yxd',
#   [['ns:m.06yxd',
#     'ns:base.aareas.schema.administrative_area.administrative_parent',
#     '?x']],
#   'South Carolina',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09c7w0',
#     'EntityName': 'United States of America'}]],
#  [21,
#   'what kind of government does the united states have today',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]],
#  [22,
#   "who were michael jackson 's brothers and sisters",
#   'm.09889g',
#   [['ns:m.09889g', 'ns:people.person.sibling_s', '?y'],
#    ['?y', 'ns:people.sibling_relationship.sibling', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.013v5j',
#     'EntityName': 'La Toya Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01s993',
#     'EntityName': 'Jackie Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01s9b9',
#     'EntityName': 'Tito Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01zmpg',
#     'EntityName': 'Jermaine Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.023_5s',
#     'EntityName': 'Marlon Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0247h4',
#     'EntityName': 'Rebbie Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04_70v',
#     'EntityName': 'Randy Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0598rr3',
#     'EntityName': "Joh'Vonnie Jackson"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0gbwp',
#     'EntityName': 'Janet Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0nf3l7y',
#     'EntityName': 'Brandon Jackson'}]],
#  [23,
#   'what is zip code for chicago illinois',
#   'm.01_d4',
#   [['ns:m.01_d4', 'ns:location.citytown.postal_codes', '?x']],
#   'Chicago',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p_k',
#     'EntityName': '60626'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p6k',
#     'EntityName': '60618'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p8l',
#     'EntityName': '60601'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p9s',
#     'EntityName': '60610'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pdj',
#     'EntityName': '60602'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pgd',
#     'EntityName': '60622'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6ph7',
#     'EntityName': '60614'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pmb',
#     'EntityName': '60607'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pnb',
#     'EntityName': '60649'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pp5',
#     'EntityName': '60660'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6ps8',
#     'EntityName': '60611'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pvy',
#     'EntityName': '60646'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pxw',
#     'EntityName': '60657'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q0k',
#     'EntityName': '60613'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q1q',
#     'EntityName': '60640'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q8p',
#     'EntityName': '60619'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q9q',
#     'EntityName': '60605'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qcm',
#     'EntityName': '60659'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qjr',
#     'EntityName': '60616'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qp4',
#     'EntityName': '60608'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qrp',
#     'EntityName': '60661'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qsj',
#     'EntityName': '60625'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qz6',
#     'EntityName': '60647'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r1z',
#     'EntityName': '60630'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r78',
#     'EntityName': '60603'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r82',
#     'EntityName': '60631'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6rf1',
#     'EntityName': '60606'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6rfw',
#     'EntityName': '60655'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6s_6',
#     'EntityName': '60634'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6s0l',
#     'EntityName': '60617'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6smy',
#     'EntityName': '60609'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6sws',
#     'EntityName': '60632'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t1b',
#     'EntityName': '60623'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t43',
#     'EntityName': '60629'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t4y',
#     'EntityName': '60652'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t5r',
#     'EntityName': '60638'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t95',
#     'EntityName': '60645'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6tgy',
#     'EntityName': '60615'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6v4j',
#     'EntityName': '60604'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6v6w',
#     'EntityName': '60637'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6y3n',
#     'EntityName': '60643'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6zk1',
#     'EntityName': '60624'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_7140',
#     'EntityName': '60653'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_71cx',
#     'EntityName': '60666'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_72xz',
#     'EntityName': '60628'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_73_n',
#     'EntityName': '60641'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_75zb',
#     'EntityName': '60612'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_77qt',
#     'EntityName': '60639'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_77x6',
#     'EntityName': '60636'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78lh',
#     'EntityName': '60651'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78nm',
#     'EntityName': '60620'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78wb',
#     'EntityName': '60654'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_795b',
#     'EntityName': '60644'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_7gfz',
#     'EntityName': '60656'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03dpqpb',
#     'EntityName': '60621'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03dpqrm',
#     'EntityName': '60633'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.065rklh',
#     'EntityName': '60642'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmf7',
#     'EntityName': '60701'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfg',
#     'EntityName': '60699'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfp',
#     'EntityName': '60697'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfx',
#     'EntityName': '60696'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmg_',
#     'EntityName': '60690'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmg3',
#     'EntityName': '60695'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgb',
#     'EntityName': '60694'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgk',
#     'EntityName': '60693'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgs',
#     'EntityName': '60691'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmh6',
#     'EntityName': '60689'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhf',
#     'EntityName': '60688'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhn',
#     'EntityName': '60687'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhw',
#     'EntityName': '60686'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmj2',
#     'EntityName': '60685'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmj9',
#     'EntityName': '60684'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjj',
#     'EntityName': '60682'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjr',
#     'EntityName': '60681'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjz',
#     'EntityName': '60680'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmk5',
#     'EntityName': '60678'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkd',
#     'EntityName': '60677'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkm',
#     'EntityName': '60675'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkv',
#     'EntityName': '60674'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqml1',
#     'EntityName': '60673'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqml8',
#     'EntityName': '60670'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmlh',
#     'EntityName': '60669'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmlq',
#     'EntityName': '60668'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmly',
#     'EntityName': '60664'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqms5',
#     'EntityName': '60290'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09sh942',
#     'EntityName': '60657-3241'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0gs227r',
#     'EntityName': '60637-1424'}]],
#  [24,
#   'what kind of system of government does the united states have',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]],
#  [25,
#   'what type of currency does the us have',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.currency_used', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09nqf',
#     'EntityName': 'United States Dollar'}]],
#  [26,
#   'what are all of michael jackson albums',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:music.artist.album', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'g.11b5q8l129',
#     'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.11bbxlkxxc',
#     'EntityName': 'Greatest Hits - HIStory Volume I'},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120jfbwf', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120n34ct', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120p50b2', 'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.120qdf98',
#     'EntityName': "Motown's Greatest Hits"},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120vbf6y', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120vhf69', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120wr8ww', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.120yrclj', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121_btq7', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121k2wyq', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121kx0gx', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121lysqn', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121n9qzq', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121v77kf', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.121vl6p3', 'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.121xqb58',
#     'EntityName': 'The Great Love Songs of Michael Jackson'},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.12221snb', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1226g4nw', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.122mr2dg', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.122n5p5k', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.122rvvwp', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.122rvxds', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.123197b2', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1231gfcz', 'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.123656pn',
#     'EntityName': '14 Greatest Hits With the Jackson 5'},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1236sqs9', 'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.1236srvy',
#     'EntityName': '18 Greatest Hits'},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1237d7hl', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1hb_fdlpy', 'EntityName': ''},
#    {'AnswerType': 'Entity', 'AnswerArgument': 'g.1q6fnpzns', 'EntityName': ''},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'g.1yxkhh_jb',
#     'EntityName': 'Their Very Best – Back to Back'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0__ljrb',
#     'EntityName': 'Best Ballads'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0105mn8y',
#     'EntityName': 'Xscape'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.010klcpt',
#     'EntityName': 'Love Never Felt So Good'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0124gpp4',
#     'EntityName': 'The Motown Years...His Greatest Hits'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.012mtk5b',
#     'EntityName': 'The Best'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.012qdqrz',
#     'EntityName': 'Love Never Felt So Good (David Morales and Eric Kupper Def mix)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.012tw152',
#     'EntityName': 'Love Never Felt So Good (Fedde Le Grand Remix)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.012vppwh',
#     'EntityName': 'Thriller 25: Limited Japanese Single Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0132tgw6',
#     'EntityName': 'Thriller (Special Edit)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0133rz52',
#     'EntityName': 'Jackson’s Paradise'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2f3',
#     'EntityName': 'Billie Jean'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2fj',
#     'EntityName': "Don't Stop 'Til You Get Enough"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2fz',
#     'EntityName': 'Stranger in Moscow'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2gc',
#     'EntityName': 'Rock With You'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2gt',
#     'EntityName': 'HIStory'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2h9',
#     'EntityName': 'Music & Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2j6',
#     'EntityName': 'The Best of Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2l9',
#     'EntityName': 'Invincible'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2mq',
#     'EntityName': 'Heal the World'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2t4',
#     'EntityName': 'In the Closet'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2tr',
#     'EntityName': 'The 12\\" Mixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl2xg',
#     'EntityName': 'You Are Not Alone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl30m',
#     'EntityName': 'Remixed Supergold'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl31m',
#     'EntityName': 'Not Guilty (Special Fan Edition)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl33y',
#     'EntityName': 'Heal the World Tour 92'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl356',
#     'EntityName': 'Black or White'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl35s',
#     'EntityName': 'Earth Song'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3bj',
#     'EntityName': 'Smooth Criminal'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3gv',
#     'EntityName': "I Just Can't Stop Loving You"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3jm',
#     'EntityName': 'Bad'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3ly',
#     'EntityName': 'You Rock My World'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3sj',
#     'EntityName': 'One More Chance'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3t4',
#     'EntityName': 'Number Ones'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3vk',
#     'EntityName': 'The Michael Jackson Mix'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3xz',
#     'EntityName': 'Instrumental Version Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl3zv',
#     'EntityName': 'Blood on the Dance Floor'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl40t',
#     'EntityName': 'Off The Wall'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl444',
#     'EntityName': 'Ben'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl45_',
#     'EntityName': 'Scream'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl452',
#     'EntityName': 'Forever, Michael'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl48b',
#     'EntityName': "They Don't Care About Us"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl4hb',
#     'EntityName': 'Blood on the Dance Floor: HIStory in the Mix'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl4k9',
#     'EntityName': 'Motown Legends'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl4l8',
#     'EntityName': 'The Remixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hl4ml',
#     'EntityName': 'Will You Be There'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01k9bm5',
#     'EntityName': 'The Wiz: Original Motion Picture Soundtrack'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01n7xgt',
#     'EntityName': 'The Best of Michael Jackson & The Jackson 5'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01n7y48',
#     'EntityName': 'Master Series: Michael Jackson with The Jackson 5'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02650xh',
#     'EntityName': 'Live in Bucharest: The Dangerous Tour'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0285mp9',
#     'EntityName': "A Collection of Michael Jackson's Oldies"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02srz6',
#     'EntityName': 'Thriller'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02st0w',
#     'EntityName': 'Dangerous'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02st1p',
#     'EntityName': 'HIStory: Past, Present and Future, Book 1'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03cj9kh',
#     'EntityName': 'Michael Jackson 25th Anniversary of Thriller'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03fzcf4',
#     'EntityName': 'Music and Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03jg4tt',
#     'EntityName': 'The Original Soul of Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03jgszc',
#     'EntityName': 'The Essential Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03xwgr7',
#     'EntityName': 'Thriller 25'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03z1ptx',
#     'EntityName': 'The Jacksons Story'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.047qwf7',
#     'EntityName': 'King of Pop'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.049rcj0',
#     'EntityName': '20th Century Masters: The Millennium Collection: The Best of Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ckkf5',
#     'EntityName': 'One Day in Your Life'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ckkff',
#     'EntityName': 'The Very Best of Michael Jackson with the Jackson Five'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ffqlg',
#     'EntityName': 'Beat It'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ffqlx',
#     'EntityName': 'Jam'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ffqm4',
#     'EntityName': 'Leave Me Alone'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ffqmd',
#     'EntityName': 'Remember the Time'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ffqmp',
#     'EntityName': 'The Way You Make Me Feel'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04mzmy4',
#     'EntityName': 'Looking Back to Yesterday'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05f522t',
#     'EntityName': 'E.T. the Extra-Terrestrial'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06_y1fq',
#     'EntityName': 'The Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06308p',
#     'EntityName': 'The Ultimate Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06mvhg',
#     'EntityName': 'Got to Be There'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06mw68',
#     'EntityName': 'Farewell My Summer Love'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06vzkfv',
#     'EntityName': 'Moonwalker'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06w2bnf',
#     'EntityName': 'The Stripped Mixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06w81qp',
#     'EntityName': 'Hello World: The Motown Solo Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07k7rqv',
#     'EntityName': 'Michael Jackson Live in Japan'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07kby3z',
#     'EntityName': 'The Remix Suite'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0805f2g',
#     'EntityName': "Michael Jackson's This Is It"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.096y7s',
#     'EntityName': 'Visionary: The Video Singles'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09yyl5',
#     'EntityName': 'Anthology'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c3xrp_',
#     'EntityName': 'The Definitive Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dl7rvt',
#     'EntityName': 'Michael'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dlk02n',
#     'EntityName': "Michael Jackson's Vision"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dmk1t4',
#     'EntityName': 'In Concert'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dnv23g',
#     'EntityName': 'Who Is It'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dvl5p3',
#     'EntityName': 'Give in to Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0dvl6z5',
#     'EntityName': '50 Best Songs: The Motown Years'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0f04tbf',
#     'EntityName': 'Inédits Songs'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0f619lx',
#     'EntityName': 'The Girl Is Mine 2008'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0fhtpqk',
#     'EntityName': 'Great Songs and Performances'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0fqrfqm',
#     'EntityName': 'All of It (Bukarest live October 92)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0fsp0fq',
#     'EntityName': 'Cry'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0ft9skn',
#     'EntityName': 'Love Songs'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0fvj81r',
#     'EntityName': 'The Girl Is Mine'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0fwcwqc',
#     'EntityName': "You Can't Win / Billie Jean"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0g6_q__',
#     'EntityName': 'Hold My Hand'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0gdw13q',
#     'EntityName': '2010/10/12'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0glt06b',
#     'EntityName': 'Promo'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h1d8yv',
#     'EntityName': 'One Night in Japan'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kbk',
#     'EntityName': 'Someone in the Dark'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kbr',
#     'EntityName': 'Someone Put Your Hand Out'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kbv',
#     'EntityName': 'Is It Scary'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kby',
#     'EntityName': 'Butterflies'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kc0',
#     'EntityName': 'Colour Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kc3',
#     'EntityName': 'The Silver Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kc6',
#     'EntityName': 'The Early Years'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kc9',
#     'EntityName': 'The Classics: A Tribute to a Legend'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcd',
#     'EntityName': 'Man Or The Music'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kch',
#     'EntityName': 'Music History 1'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcl',
#     'EntityName': '1988-03-05: Madison Square Garden, New York, NY, USA'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcp',
#     'EntityName': '1988: Bad Tour Live in Rotterdam 1988'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcs',
#     'EntityName': 'The Bad Mixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcw',
#     'EntityName': 'Remind: The Remix'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kcz',
#     'EntityName': 'Human Nature'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kd1',
#     'EntityName': 'Remixes, Volume 1'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h32kd4',
#     'EntityName': 'The Megamixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h3twc8',
#     'EntityName': 'Love Songs'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h7n1qw',
#     'EntityName': 'Immortal'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0hz6q1j',
#     'EntityName': 'Michael Jackson: Number Ones'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j46mk5',
#     'EntityName': 'Icon'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0jwt60n',
#     'EntityName': 'Bad 25'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0jwzllk',
#     'EntityName': 'Live at Wembley July 16, 1988'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0q8flcq',
#     'EntityName': 'The Universal Masters Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0q9j6g_',
#     'EntityName': 'Live & Alive'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0qdkdmy',
#     'EntityName': 'Another Part of Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0qz95jy',
#     'EntityName': 'Thriller'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0rpv45n',
#     'EntityName': 'Dirty Diana'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0shhsh8',
#     'EntityName': 'Ease on Down the Road'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v_7274',
#     'EntityName': 'Liberian Girl'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v_756d',
#     'EntityName': 'Gone Too Soon'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3h_9j',
#     'EntityName': 'Hollywood Tonight'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3h3mr',
#     'EntityName': "Selections from Michael Jackson's This Is It"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3hkhk',
#     'EntityName': 'Dear Michael: The Motown Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3hlrc',
#     'EntityName': 'Mellow Michael Jackson – Never Can Say Goodbye'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3j1bt',
#     'EntityName': 'Behind the Mask'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3l6q9',
#     'EntityName': "I'm So Blue"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3l8rh',
#     'EntityName': 'Bad (Afrojack Remix) (DJ Buddha Edit)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3lbgm',
#     'EntityName': 'Is It Scary/Threatened/Thriller (Immortal Version)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3lczh',
#     'EntityName': 'This Place Hotel/Smooth Criminal/Dangerous (Immortal Version)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3lg4y',
#     'EntityName': 'Dancing Machine/Blame It on the Boogie (Immortal Version)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3ljxq',
#     'EntityName': "I'll Be There (Immortal version)"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3m6m6',
#     'EntityName': "Wanna Be Startin' Somethin' (Immortal Version)"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3m7rl',
#     'EntityName': "You Are Not Alone/I Just Can't Stop Loving You (Immortal Version)"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3m9wb',
#     'EntityName': 'Immortal Megamix'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3mhws',
#     'EntityName': "I Just Can't Stop Loving You/Don't Be Messin' 'Round"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0v3mkn2',
#     'EntityName': 'All in Your Name (with Barry Gibb)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vsld1y',
#     'EntityName': 'A Brand New Day / Liberation Ballet - A Brand New Day'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vt7sqb',
#     'EntityName': 'What More Can I Give'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyl_9c',
#     'EntityName': 'Mellow Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vylbzr',
#     'EntityName': 'Best Selection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyllbh',
#     'EntityName': 'La Légende de la Pop'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vym1p0',
#     'EntityName': 'Les 50 Plus Belles Chansons'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vym6w6',
#     'EntityName': 'Tour Souvenir Pack'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vym8jy',
#     'EntityName': 'Singles Souvenir Pack'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vymdk6',
#     'EntityName': '9 Singles Pack'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyn4p1',
#     'EntityName': 'Dangerous - The Remix Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyn9rb',
#     'EntityName': 'Hiroshi Fujiwara & K.U.D.O. Presents: Michael Jackson / Jackson 5 Remixes'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vynj_2',
#     'EntityName': 'Got to Be There'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vynnqc',
#     'EntityName': "Rockin' Robin"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vynqxt',
#     'EntityName': 'I Wanna Be Where You Are'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vypv96',
#     'EntityName': 'Ben'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyq2h2',
#     'EntityName': "With a Child's Heart"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyqb_7',
#     'EntityName': 'Happy'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyqjt0',
#     'EntityName': 'Music and Me'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyqrc0',
#     'EntityName': "We're Almost There"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vyqv7z',
#     'EntityName': 'Just a Little Bit of You'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzwxwg',
#     'EntityName': 'One Day in Your Life'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzxkrq',
#     'EntityName': 'Off the Wall'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzy1n3',
#     'EntityName': "She's Out of My Life"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzyc_d',
#     'EntityName': 'Girlfriend'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzyy2k',
#     'EntityName': 'Man in the Mirror'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w44_17',
#     'EntityName': 'Os Grandes Sucessos, Vol. 2'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w44_70',
#     'EntityName': 'Motown Superstar Series, Vol. 7'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w44_kg',
#     'EntityName': 'Superstar'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w44_qy',
#     'EntityName': 'Michael Jackson & The Jackson 5'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w44zny',
#     'EntityName': 'Portrait of Michael Jackson / Portrait of Jackson 5'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w45061',
#     'EntityName': "Ain't No Sunshine"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w450nh',
#     'EntityName': "Rockin' Robin"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w4513n',
#     'EntityName': 'Michael Jackson Story'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w452dl',
#     'EntityName': 'Ghosts – Deluxe Collector Box Set'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w45314',
#     'EntityName': 'Classic – The Universal Masters Collection'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w46_vj',
#     'EntityName': 'P.Y.T. (Pretty Young Thing)'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w46vmn',
#     'EntityName': 'Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w46w71',
#     'EntityName': 'Visionary Remixes - EP'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w46wmh',
#     'EntityName': 'The Instrumental Hits of Michael Jackson'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w46yg8',
#     'EntityName': 'Pure Michael: Motown a Cappella'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0w471yb',
# ...
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06kd6y',
#     'EntityName': 'Battle of Fort Duquesne'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07h0q2',
#     'EntityName': 'Battle of the Assunpink Creek'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.08knpp',
#     'EntityName': 'Fortification of Dorchester Heights'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09r3f',
#     'EntityName': 'French and Indian War'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0b364c',
#     'EntityName': 'Battle of Fort Washington'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0bxl0n',
#     'EntityName': 'Philadelphia campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0drwsm9',
#     'EntityName': 'Yorktown campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h42fq',
#     'EntityName': 'Battle of White Marsh'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0jnh',
#     'EntityName': 'American Revolutionary War'}]],
#  [45,
#   'what war was george washington president during',
#   'm.034rd',
#   [['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y'],
#    ['?y', 'ns:military.military_command.military_conflict', '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.014pd3',
#     'EntityName': 'Battle of Brandywine'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.014s1b',
#     'EntityName': 'Siege of Yorktown'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01bh42',
#     'EntityName': 'Treaty of Alliance'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01g09p',
#     'EntityName': 'Battle of Long Island'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01g0dx',
#     'EntityName': 'Battle of Princeton'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01gphc',
#     'EntityName': 'Braddock Expedition'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01hgpt',
#     'EntityName': 'Battle of Trenton'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01jnys',
#     'EntityName': 'Siege of Boston'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01k0s4',
#     'EntityName': 'Battle of Monmouth'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.020_gf',
#     'EntityName': 'Battle of Germantown'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0247w9',
#     'EntityName': 'Battle of White Plains'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fmsl',
#     'EntityName': 'New York and New Jersey campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02fnwp',
#     'EntityName': 'Battle of Harlem Heights'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02g1n3',
#     'EntityName': "Landing at Kip's Bay"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.02pjz77',
#     'EntityName': 'Battle of the Clouds'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04m2k9',
#     'EntityName': "Battle of Pell's Point"},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05b6mx0',
#     'EntityName': 'Battle of the Monongahela'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.05f78h',
#     'EntityName': 'Battle of Fort Necessity'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.062pq1',
#     'EntityName': 'Boston campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.066xwk',
#     'EntityName': 'Battle of Jumonville Glen'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06bjm',
#     'EntityName': 'Quasi-War'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06kd6y',
#     'EntityName': 'Battle of Fort Duquesne'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07h0q2',
#     'EntityName': 'Battle of the Assunpink Creek'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.08knpp',
#     'EntityName': 'Fortification of Dorchester Heights'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09r3f',
#     'EntityName': 'French and Indian War'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0b364c',
#     'EntityName': 'Battle of Fort Washington'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0bxl0n',
#     'EntityName': 'Philadelphia campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0drwsm9',
#     'EntityName': 'Yorktown campaign'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0h42fq',
#     'EntityName': 'Battle of White Marsh'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0jnh',
#     'EntityName': 'American Revolutionary War'}]],
#  [46,
#   'what school did michael jackson attend',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:people.person.education', '?y'],
#    ['?y', 'ns:education.education.institution', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06lhpy',
#     'EntityName': 'Montclair College Preparatory School'}]],
#  [47,
#   'what was the cause of death of michael jackson',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:people.deceased_person.cause_of_death', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0gg4h',
#     'EntityName': 'Cardiac arrest'}]],
#  [48,
#   'what is the capital city of texas usa',
#   'm.07b_l',
#   [['ns:m.07b_l', 'ns:location.us_state.capital', '?x']],
#   'Texas',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0vzm',
#     'EntityName': 'Austin'}]],
#  [49,
#   'who influenced michael jackson',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:influence.influence_node.influenced_by', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01b9db',
#     'EntityName': 'Redd Foxx'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01lc5',
#     'EntityName': 'Charlie Chaplin'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0407f',
#     'EntityName': 'James Brown'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.04ct6p',
#     'EntityName': 'Nipsey Russell'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.081nh',
#     'EntityName': 'Walt Disney'}]],
#  [50,
#   'what zip code is chicago il',
#   'm.01_d4',
#   [['ns:m.01_d4', 'ns:location.citytown.postal_codes', '?x']],
#   'Chicago',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p_k',
#     'EntityName': '60626'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p6k',
#     'EntityName': '60618'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p8l',
#     'EntityName': '60601'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6p9s',
#     'EntityName': '60610'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pdj',
#     'EntityName': '60602'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pgd',
#     'EntityName': '60622'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6ph7',
#     'EntityName': '60614'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pmb',
#     'EntityName': '60607'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pnb',
#     'EntityName': '60649'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pp5',
#     'EntityName': '60660'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6ps8',
#     'EntityName': '60611'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pvy',
#     'EntityName': '60646'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6pxw',
#     'EntityName': '60657'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q0k',
#     'EntityName': '60613'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q1q',
#     'EntityName': '60640'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q8p',
#     'EntityName': '60619'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6q9q',
#     'EntityName': '60605'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qcm',
#     'EntityName': '60659'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qjr',
#     'EntityName': '60616'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qp4',
#     'EntityName': '60608'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qrp',
#     'EntityName': '60661'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qsj',
#     'EntityName': '60625'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6qz6',
#     'EntityName': '60647'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r1z',
#     'EntityName': '60630'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r78',
#     'EntityName': '60603'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6r82',
#     'EntityName': '60631'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6rf1',
#     'EntityName': '60606'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6rfw',
#     'EntityName': '60655'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6s_6',
#     'EntityName': '60634'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6s0l',
#     'EntityName': '60617'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6smy',
#     'EntityName': '60609'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6sws',
#     'EntityName': '60632'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t1b',
#     'EntityName': '60623'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t43',
#     'EntityName': '60629'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t4y',
#     'EntityName': '60652'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t5r',
#     'EntityName': '60638'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6t95',
#     'EntityName': '60645'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6tgy',
#     'EntityName': '60615'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6v4j',
#     'EntityName': '60604'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6v6w',
#     'EntityName': '60637'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6y3n',
#     'EntityName': '60643'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_6zk1',
#     'EntityName': '60624'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_7140',
#     'EntityName': '60653'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_71cx',
#     'EntityName': '60666'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_72xz',
#     'EntityName': '60628'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_73_n',
#     'EntityName': '60641'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_75zb',
#     'EntityName': '60612'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_77qt',
#     'EntityName': '60639'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_77x6',
#     'EntityName': '60636'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78lh',
#     'EntityName': '60651'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78nm',
#     'EntityName': '60620'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_78wb',
#     'EntityName': '60654'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_795b',
#     'EntityName': '60644'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01_7gfz',
#     'EntityName': '60656'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03dpqpb',
#     'EntityName': '60621'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03dpqrm',
#     'EntityName': '60633'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.065rklh',
#     'EntityName': '60642'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmf7',
#     'EntityName': '60701'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfg',
#     'EntityName': '60699'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfp',
#     'EntityName': '60697'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmfx',
#     'EntityName': '60696'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmg_',
#     'EntityName': '60690'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmg3',
#     'EntityName': '60695'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgb',
#     'EntityName': '60694'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgk',
#     'EntityName': '60693'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmgs',
#     'EntityName': '60691'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmh6',
#     'EntityName': '60689'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhf',
#     'EntityName': '60688'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhn',
#     'EntityName': '60687'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmhw',
#     'EntityName': '60686'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmj2',
#     'EntityName': '60685'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmj9',
#     'EntityName': '60684'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjj',
#     'EntityName': '60682'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjr',
#     'EntityName': '60681'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmjz',
#     'EntityName': '60680'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmk5',
#     'EntityName': '60678'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkd',
#     'EntityName': '60677'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkm',
#     'EntityName': '60675'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmkv',
#     'EntityName': '60674'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqml1',
#     'EntityName': '60673'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqml8',
#     'EntityName': '60670'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmlh',
#     'EntityName': '60669'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmlq',
#     'EntityName': '60668'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqmly',
#     'EntityName': '60664'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.07nqms5',
#     'EntityName': '60290'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.09sh942',
#     'EntityName': '60657-3241'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0gs227r',
#     'EntityName': '60637-1424'}]],
#  [51,
#   'what state in chicago in',
#   'm.01_d4',
#   [['ns:m.01_d4', 'ns:base.biblioness.bibs_location.state', '?x']],
#   'Chicago',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.03v0t',
#     'EntityName': 'Illinois'}]],
#  [52,
#   'where was george washington originally from',
#   'm.034rd',
#   [['ns:m.034rd', 'ns:people.person.place_of_birth', '?x']],
#   'George Washington',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0mmyl',
#     'EntityName': 'Westmoreland County'}]],
#  [53,
#   'where did michael jackson went to school',
#   'm.09889g',
#   [['ns:m.09889g', 'ns:people.person.education', '?y'],
#    ['?y', 'ns:education.education.institution', '?x']],
#   'Michael Jackson',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06lhpy',
#     'EntityName': 'Montclair College Preparatory School'}]],
#  [54,
#   'what year did michael jordan get drafted',
#   'm.054c1',
#   [['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y'],
#    ['?y', 'ns:sports.sports_league_draft_pick.draft', '?x']],
#   'Michael Jordan',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.06jncs',
#     'EntityName': '1984 NBA draft'}]],
#  [56,
#   'what form of government do we have in the usa',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]],
#  [57,
#   'what kind government does the us have',
#   'm.09c7w0',
#   [['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']],
#   'United States of America',
#   [{'AnswerType': 'Entity',
#     'AnswerArgument': 'm.01d9r3',
#     'EntityName': 'Presidential system'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0c9rw5',
#     'EntityName': 'Constitutional republic'},
#    {'AnswerType': 'Entity',
#     'AnswerArgument': 'm.0j729',
#     'EntityName': 'Federal republic'}]]]

# %%
question = queries[3]
idx, eng_question, start_node, question_query, eng_start_node, actual_answer = question

question
# Out:
# [4,
#  'what war was george washington associated with',
#  'm.034rd',
#  [['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y'],
#   ['?y', 'ns:military.military_command.military_conflict', '?x']],
#  'George Washington',
#  [{'AnswerType': 'Entity',
#    'AnswerArgument': 'm.014pd3',
#    'EntityName': 'Battle of Brandywine'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.014s1b',
#    'EntityName': 'Siege of Yorktown'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01bh42',
#    'EntityName': 'Treaty of Alliance'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01g09p',
#    'EntityName': 'Battle of Long Island'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01g0dx',
#    'EntityName': 'Battle of Princeton'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01gphc',
#    'EntityName': 'Braddock Expedition'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01hgpt',
#    'EntityName': 'Battle of Trenton'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01jnys',
#    'EntityName': 'Siege of Boston'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.01k0s4',
#    'EntityName': 'Battle of Monmouth'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.020_gf',
#    'EntityName': 'Battle of Germantown'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0247w9',
#    'EntityName': 'Battle of White Plains'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.02fmsl',
#    'EntityName': 'New York and New Jersey campaign'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.02fnwp',
#    'EntityName': 'Battle of Harlem Heights'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.02g1n3',
#    'EntityName': "Landing at Kip's Bay"},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.02pjz77',
#    'EntityName': 'Battle of the Clouds'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.04m2k9',
#    'EntityName': "Battle of Pell's Point"},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.05b6mx0',
#    'EntityName': 'Battle of the Monongahela'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.05f78h',
#    'EntityName': 'Battle of Fort Necessity'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.062pq1',
#    'EntityName': 'Boston campaign'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.066xwk',
#    'EntityName': 'Battle of Jumonville Glen'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.06bjm',
#    'EntityName': 'Quasi-War'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.06kd6y',
#    'EntityName': 'Battle of Fort Duquesne'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.07h0q2',
#    'EntityName': 'Battle of the Assunpink Creek'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.08knpp',
#    'EntityName': 'Fortification of Dorchester Heights'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.09r3f',
#    'EntityName': 'French and Indian War'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0b364c',
#    'EntityName': 'Battle of Fort Washington'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0bxl0n',
#    'EntityName': 'Philadelphia campaign'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0drwsm9',
#    'EntityName': 'Yorktown campaign'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0h42fq',
#    'EntityName': 'Battle of White Marsh'},
#   {'AnswerType': 'Entity',
#    'AnswerArgument': 'm.0jnh',
#    'EntityName': 'American Revolutionary War'}]]

# %%
def traverse_knowlegde_graph(knowledge_graph: defaultdict, start_node: str):
    SIMILARITY_THRESHOLD = 0.3

    pq = []
    pq.append((0, start_node))
    
    visited = set()
    answer_nodes = set()
    
    while len(pq) > 0:
        sim_score, curr_node = heapq.heappop(pq)
    
        if curr_node in visited:
            continue
    
        visited.add(curr_node)
    
        sim_score = -1 * sim_score
        if sim_score >= SIMILARITY_THRESHOLD:
            answer_nodes.add(curr_node)
    
        for neighbors in knowledge_graph[curr_node]:
            relation, adj_entity = neighbors
            
            relation = "ns:" + relation
            sim_score = get_rel_score_word2vecbase(relation, eng_question)
            
            heapq.heappush(pq, (-sim_score, adj_entity))

    return answer_nodes

# %%
TP, FP, FN = 0, 0, 0
for query in tqdm(queries, desc="Answering Queries"):
    idx, eng_question, start_node, question_query, eng_start_node, actual_answers = query
    
    answer_nodes = traverse_knowlegde_graph(knowledge_graph, start_node)
    actual_answers = set(x["AnswerArgument"] for x in actual_answers)

    TP += len(answer_nodes.intersection(actual_answers))
    FP += len(answer_nodes.difference(actual_answers))
    FN += len(actual_answers.difference(answer_nodes))

f1_score = (2 * TP) / (2 * TP + FP + FN)
print(f"F1 score of the custom Knowledge Base Question Answering: {f1_score:.3f}")
# Out:
# Answering Queries: 100%|████████████████████████| 56/56 [00:29<00:00,  1.88it/s]
# F1 score of the custom Knowledge Base Question Answering: 0.336
